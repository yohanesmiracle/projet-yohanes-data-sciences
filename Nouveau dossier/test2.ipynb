# %% [markdown]
# ---
#
#
# <img decoding="async" src="https://salonimmigration.com/wp-content/uploads/2021/07/Universite_Teluq_Logo_255x158-1.png" alt="Logo Universite TELUQ" width="555" height="458" class="size-full wp-image-1922 alignleft" />
#
#
# Yohanes Elitsa
# ---
#
#
#
#
# # c'est ici que tout mon code commence

# %%
import wbgapi as wb
import requests
import plotly.express as px
import pandas as pd

# %%
wb.economy.info()
# Out:
# id    value                                                 region    incomeLevel
# ----  ----------------------------------------------------  --------  -------------
# ABW   Aruba                                                 LCN       HIC
# AFE   Africa Eastern and Southern
# AFG   Afghanistan                                           SAS       LIC
# AFW   Africa Western and Central
# AGO   Angola                                                SSF       LMC
# ALB   Albania                                               ECS       UMC
# AND   Andorra                                               ECS       HIC
# ARB   Arab World
# ARE   United Arab Emirates                                  MEA       HIC
# ARG   Argentina                                             LCN       UMC
# ARM   Armenia                                               ECS       UMC
# ASM   American Samoa                                        EAS       HIC
# ATG   Antigua and Barbuda                                   LCN       HIC
# AUS   Australia                                             EAS       HIC
# AUT   Austria                                               ECS       HIC
# AZE   Azerbaijan                                            ECS       UMC
# BDI   Burundi                                               SSF       LIC
# BEL   Belgium                                               ECS       HIC
# BEN   Benin                                                 SSF       LMC
# BFA   Burkina Faso                                          SSF       LIC
# BGD   Bangladesh                                            SAS       LMC
# BGR   Bulgaria                                              ECS       UMC
# BHR   Bahrain                                               MEA       HIC
# BHS   Bahamas, The                                          LCN       HIC
# BIH   Bosnia and Herzegovina                                ECS       UMC
# BLR   Belarus                                               ECS       UMC
# BLZ   Belize                                                LCN       UMC
# BMU   Bermuda                                               NAC       HIC
# BOL   Bolivia                                               LCN       LMC
# BRA   Brazil                                                LCN       UMC
# BRB   Barbados                                              LCN       HIC
# BRN   Brunei Darussalam                                     EAS       HIC
# BTN   Bhutan                                                SAS       LMC
# BWA   Botswana                                              SSF       UMC
# CAF   Central African Republic                              SSF       LIC
# CAN   Canada                                                NAC       HIC
# CEB   Central Europe and the Baltics
# CHE   Switzerland                                           ECS       HIC
# CHI   Channel Islands                                       ECS       HIC
# CHL   Chile                                                 LCN       HIC
# CHN   China                                                 EAS       UMC
# CIV   Cote d'Ivoire                                         SSF       LMC
# CMR   Cameroon                                              SSF       LMC
# COD   Congo, Dem. Rep.                                      SSF       LIC
# COG   Congo, Rep.                                           SSF       LMC
# COL   Colombia                                              LCN       UMC
# COM   Comoros                                               SSF       LMC
# CPV   Cabo Verde                                            SSF       LMC
# CRI   Costa Rica                                            LCN       UMC
# CSS   Caribbean small states
# CUB   Cuba                                                  LCN       UMC
# CUW   Curacao                                               LCN       HIC
# CYM   Cayman Islands                                        LCN       HIC
# CYP   Cyprus                                                ECS       HIC
# CZE   Czechia                                               ECS       HIC
# DEU   Germany                                               ECS       HIC
# DJI   Djibouti                                              MEA       LMC
# DMA   Dominica                                              LCN       UMC
# DNK   Denmark                                               ECS       HIC
# DOM   Dominican Republic                                    LCN       UMC
# DZA   Algeria                                               MEA       LMC
# EAP   East Asia & Pacific (excluding high income)
# EAR   Early-demographic dividend
# EAS   East Asia & Pacific
# ECA   Europe & Central Asia (excluding high income)
# ECS   Europe & Central Asia
# ECU   Ecuador                                               LCN       UMC
# EGY   Egypt, Arab Rep.                                      MEA       LMC
# EMU   Euro area
# ERI   Eritrea                                               SSF       LIC
# ESP   Spain                                                 ECS       HIC
# EST   Estonia                                               ECS       HIC
# ETH   Ethiopia                                              SSF       LIC
# EUU   European Union
# FCS   Fragile and conflict affected situations
# FIN   Finland                                               ECS       HIC
# FJI   Fiji                                                  EAS       UMC
# FRA   France                                                ECS       HIC
# FRO   Faroe Islands                                         ECS       HIC
# FSM   Micronesia, Fed. Sts.                                 EAS       LMC
# GAB   Gabon                                                 SSF       UMC
# GBR   United Kingdom                                        ECS       HIC
# GEO   Georgia                                               ECS       UMC
# GHA   Ghana                                                 SSF       LMC
# GIB   Gibraltar                                             ECS       HIC
# GIN   Guinea                                                SSF       LMC
# GMB   Gambia, The                                           SSF       LIC
# GNB   Guinea-Bissau                                         SSF       LIC
# GNQ   Equatorial Guinea                                     SSF       UMC
# GRC   Greece                                                ECS       HIC
# GRD   Grenada                                               LCN       UMC
# GRL   Greenland                                             ECS       HIC
# GTM   Guatemala                                             LCN       UMC
# GUM   Guam                                                  EAS       HIC
# GUY   Guyana                                                LCN       HIC
# HIC   High income
# HKG   Hong Kong SAR, China                                  EAS       HIC
# HND   Honduras                                              LCN       LMC
# HPC   Heavily indebted poor countries (HIPC)
# HRV   Croatia                                               ECS       HIC
# HTI   Haiti                                                 LCN       LMC
# HUN   Hungary                                               ECS       HIC
# IBD   IBRD only
# IBT   IDA & IBRD total
# IDA   IDA total
# IDB   IDA blend
# IDN   Indonesia                                             EAS       UMC
# IDX   IDA only
# IMN   Isle of Man                                           ECS       HIC
# IND   India                                                 SAS       LMC
# INX   Not classified
# IRL   Ireland                                               ECS       HIC
# IRN   Iran, Islamic Rep.                                    MEA       LMC
# IRQ   Iraq                                                  MEA       UMC
# ISL   Iceland                                               ECS       HIC
# ISR   Israel                                                MEA       HIC
# ITA   Italy                                                 ECS       HIC
# JAM   Jamaica                                               LCN       UMC
# JOR   Jordan                                                MEA       LMC
# JPN   Japan                                                 EAS       HIC
# KAZ   Kazakhstan                                            ECS       UMC
# KEN   Kenya                                                 SSF       LMC
# KGZ   Kyrgyz Republic                                       ECS       LMC
# KHM   Cambodia                                              EAS       LMC
# KIR   Kiribati                                              EAS       LMC
# KNA   St. Kitts and Nevis                                   LCN       HIC
# KOR   Korea, Rep.                                           EAS       HIC
# KWT   Kuwait                                                MEA       HIC
# LAC   Latin America & Caribbean (excluding high income)
# LAO   Lao PDR                                               EAS       LMC
# LBN   Lebanon                                               MEA       LMC
# LBR   Liberia                                               SSF       LIC
# LBY   Libya                                                 MEA       UMC
# LCA   St. Lucia                                             LCN       UMC
# LCN   Latin America & Caribbean
# LDC   Least developed countries: UN classification
# LIC   Low income
# LIE   Liechtenstein                                         ECS       HIC
# LKA   Sri Lanka                                             SAS       LMC
# LMC   Lower middle income
# LMY   Low & middle income
# LSO   Lesotho                                               SSF       LMC
# LTE   Late-demographic dividend
# LTU   Lithuania                                             ECS       HIC
# LUX   Luxembourg                                            ECS       HIC
# LVA   Latvia                                                ECS       HIC
# MAC   Macao SAR, China                                      EAS       HIC
# MAF   St. Martin (French part)                              LCN       HIC
# MAR   Morocco                                               MEA       LMC
# MCO   Monaco                                                ECS       HIC
# MDA   Moldova                                               ECS       UMC
# MDG   Madagascar                                            SSF       LIC
# MDV   Maldives                                              SAS       UMC
# MEA   Middle East & North Africa
# MEX   Mexico                                                LCN       UMC
# MHL   Marshall Islands                                      EAS       UMC
# MIC   Middle income
# MKD   North Macedonia                                       ECS       UMC
# MLI   Mali                                                  SSF       LIC
# MLT   Malta                                                 MEA       HIC
# MMR   Myanmar                                               EAS       LMC
# MNA   Middle East & North Africa (excluding high income)
# MNE   Montenegro                                            ECS       UMC
# MNG   Mongolia                                              EAS       LMC
# MNP   Northern Mariana Islands                              EAS       HIC
# MOZ   Mozambique                                            SSF       LIC
# MRT   Mauritania                                            SSF       LMC
# MUS   Mauritius                                             SSF       UMC
# MWI   Malawi                                                SSF       LIC
# MYS   Malaysia                                              EAS       UMC
# NAC   North America
# NAM   Namibia                                               SSF       UMC
# NCL   New Caledonia                                         EAS       HIC
# NER   Niger                                                 SSF       LIC
# NGA   Nigeria                                               SSF       LMC
# NIC   Nicaragua                                             LCN       LMC
# NLD   Netherlands                                           ECS       HIC
# NOR   Norway                                                ECS       HIC
# NPL   Nepal                                                 SAS       LMC
# NRU   Nauru                                                 EAS       HIC
# NZL   New Zealand                                           EAS       HIC
# OED   OECD members
# OMN   Oman                                                  MEA       HIC
# OSS   Other small states
# PAK   Pakistan                                              SAS       LMC
# PAN   Panama                                                LCN       HIC
# PER   Peru                                                  LCN       UMC
# PHL   Philippines                                           EAS       LMC
# PLW   Palau                                                 EAS       UMC
# PNG   Papua New Guinea                                      EAS       LMC
# POL   Poland                                                ECS       HIC
# PRE   Pre-demographic dividend
# PRI   Puerto Rico                                           LCN       HIC
# PRK   Korea, Dem. People's Rep.                             EAS       LIC
# PRT   Portugal                                              ECS       HIC
# PRY   Paraguay                                              LCN       UMC
# PSE   West Bank and Gaza                                    MEA       UMC
# PSS   Pacific island small states
# PST   Post-demographic dividend
# PYF   French Polynesia                                      EAS       HIC
# QAT   Qatar                                                 MEA       HIC
# ROU   Romania                                               ECS       HIC
# RUS   Russian Federation                                    ECS       UMC
# RWA   Rwanda                                                SSF       LIC
# SAS   South Asia
# SAU   Saudi Arabia                                          MEA       HIC
# SDN   Sudan                                                 SSF       LIC
# SEN   Senegal                                               SSF       LMC
# SGP   Singapore                                             EAS       HIC
# SLB   Solomon Islands                                       EAS       LMC
# SLE   Sierra Leone                                          SSF       LIC
# SLV   El Salvador                                           LCN       UMC
# SMR   San Marino                                            ECS       HIC
# SOM   Somalia                                               SSF       LIC
# SRB   Serbia                                                ECS       UMC
# SSA   Sub-Saharan Africa (excluding high income)
# SSD   South Sudan                                           SSF       LIC
# SSF   Sub-Saharan Africa
# SST   Small states
# STP   Sao Tome and Principe                                 SSF       LMC
# SUR   Suriname                                              LCN       UMC
# SVK   Slovak Republic                                       ECS       HIC
# SVN   Slovenia                                              ECS       HIC
# SWE   Sweden                                                ECS       HIC
# SWZ   Eswatini                                              SSF       LMC
# SXM   Sint Maarten (Dutch part)                             LCN       HIC
# SYC   Seychelles                                            SSF       HIC
# SYR   Syrian Arab Republic                                  MEA       LIC
# TCA   Turks and Caicos Islands                              LCN       HIC
# TCD   Chad                                                  SSF       LIC
# TEA   East Asia & Pacific (IDA & IBRD countries)
# TEC   Europe & Central Asia (IDA & IBRD countries)
# TGO   Togo                                                  SSF       LIC
# THA   Thailand                                              EAS       UMC
# TJK   Tajikistan                                            ECS       LMC
# TKM   Turkmenistan                                          ECS       UMC
# TLA   Latin America & the Caribbean (IDA & IBRD countries)
# TLS   Timor-Leste                                           EAS       LMC
# TMN   Middle East & North Africa (IDA & IBRD countries)
# TON   Tonga                                                 EAS       UMC
# TSA   South Asia (IDA & IBRD)
# TSS   Sub-Saharan Africa (IDA & IBRD countries)
# TTO   Trinidad and Tobago                                   LCN       HIC
# TUN   Tunisia                                               MEA       LMC
# TUR   Turkiye                                               ECS       UMC
# TUV   Tuvalu                                                EAS       UMC
# TZA   Tanzania                                              SSF       LMC
# UGA   Uganda                                                SSF       LIC
# UKR   Ukraine                                               ECS       LMC
# UMC   Upper middle income
# URY   Uruguay                                               LCN       HIC
# USA   United States                                         NAC       HIC
# UZB   Uzbekistan                                            ECS       LMC
# VCT   St. Vincent and the Grenadines                        LCN       UMC
# VEN   Venezuela, RB                                         LCN       INX
# VGB   British Virgin Islands                                LCN       HIC
# VIR   Virgin Islands (U.S.)                                 LCN       HIC
# VNM   Viet Nam                                              EAS       LMC
# VUT   Vanuatu                                               EAS       LMC
# WLD   World
# WSM   Samoa                                                 EAS       LMC
# XKX   Kosovo                                                ECS       UMC
# YEM   Yemen, Rep.                                           MEA       LIC
# ZAF   South Africa                                          SSF       UMC
# ZMB   Zambia                                                SSF       LMC
# ZWE   Zimbabwe                                              SSF       LMC
#       266 elements

# %%
wb.economy.DataFrame()
# Out:
#                             name  aggregate  longitude  latitude region  \
# id
# ABW                        Aruba      False   -70.0167  12.51670    LCN
# AFE  Africa Eastern and Southern       True        NaN       NaN
# AFG                  Afghanistan      False    69.1761  34.52280    SAS
# AFW   Africa Western and Central       True        NaN       NaN
# AGO                       Angola      False    13.2420  -8.81155    SSF
# ..                           ...        ...        ...       ...    ...
# XKX                       Kosovo      False    20.9260  42.56500    ECS
# YEM                  Yemen, Rep.      False    44.2075  15.35200    MEA
# ZAF                 South Africa      False    28.1871 -25.74600    SSF
# ZMB                       Zambia      False    28.2937 -15.39820    SSF
# ZWE                     Zimbabwe      False    31.0672 -17.83120    SSF
#
#     adminregion lendingType incomeLevel capitalCity
# id
# ABW                     LNX         HIC  Oranjestad
# AFE
# AFG         SAS         IDX         LIC       Kabul
# AFW
# AGO         SSA         IBD         LMC      Luanda
# ..          ...         ...         ...         ...
# XKX         ECA         IDX         UMC    Pristina
# YEM         MNA         IDX         LIC      Sana'a
# ZAF         SSA         IBD         UMC    Pretoria
# ZMB         SSA         IDX         LMC      Lusaka
# ZWE         SSA         IDB         LMC      Harare
#
# [266 rows x 9 columns]

# %%
wb.economy.info()
# Out:
# id    value                                                 region    incomeLevel
# ----  ----------------------------------------------------  --------  -------------
# ABW   Aruba                                                 LCN       HIC
# AFE   Africa Eastern and Southern
# AFG   Afghanistan                                           SAS       LIC
# AFW   Africa Western and Central
# AGO   Angola                                                SSF       LMC
# ALB   Albania                                               ECS       UMC
# AND   Andorra                                               ECS       HIC
# ARB   Arab World
# ARE   United Arab Emirates                                  MEA       HIC
# ARG   Argentina                                             LCN       UMC
# ARM   Armenia                                               ECS       UMC
# ASM   American Samoa                                        EAS       HIC
# ATG   Antigua and Barbuda                                   LCN       HIC
# AUS   Australia                                             EAS       HIC
# AUT   Austria                                               ECS       HIC
# AZE   Azerbaijan                                            ECS       UMC
# BDI   Burundi                                               SSF       LIC
# BEL   Belgium                                               ECS       HIC
# BEN   Benin                                                 SSF       LMC
# BFA   Burkina Faso                                          SSF       LIC
# BGD   Bangladesh                                            SAS       LMC
# BGR   Bulgaria                                              ECS       UMC
# BHR   Bahrain                                               MEA       HIC
# BHS   Bahamas, The                                          LCN       HIC
# BIH   Bosnia and Herzegovina                                ECS       UMC
# BLR   Belarus                                               ECS       UMC
# BLZ   Belize                                                LCN       UMC
# BMU   Bermuda                                               NAC       HIC
# BOL   Bolivia                                               LCN       LMC
# BRA   Brazil                                                LCN       UMC
# BRB   Barbados                                              LCN       HIC
# BRN   Brunei Darussalam                                     EAS       HIC
# BTN   Bhutan                                                SAS       LMC
# BWA   Botswana                                              SSF       UMC
# CAF   Central African Republic                              SSF       LIC
# CAN   Canada                                                NAC       HIC
# CEB   Central Europe and the Baltics
# CHE   Switzerland                                           ECS       HIC
# CHI   Channel Islands                                       ECS       HIC
# CHL   Chile                                                 LCN       HIC
# CHN   China                                                 EAS       UMC
# CIV   Cote d'Ivoire                                         SSF       LMC
# CMR   Cameroon                                              SSF       LMC
# COD   Congo, Dem. Rep.                                      SSF       LIC
# COG   Congo, Rep.                                           SSF       LMC
# COL   Colombia                                              LCN       UMC
# COM   Comoros                                               SSF       LMC
# CPV   Cabo Verde                                            SSF       LMC
# CRI   Costa Rica                                            LCN       UMC
# CSS   Caribbean small states
# CUB   Cuba                                                  LCN       UMC
# CUW   Curacao                                               LCN       HIC
# CYM   Cayman Islands                                        LCN       HIC
# CYP   Cyprus                                                ECS       HIC
# CZE   Czechia                                               ECS       HIC
# DEU   Germany                                               ECS       HIC
# DJI   Djibouti                                              MEA       LMC
# DMA   Dominica                                              LCN       UMC
# DNK   Denmark                                               ECS       HIC
# DOM   Dominican Republic                                    LCN       UMC
# DZA   Algeria                                               MEA       LMC
# EAP   East Asia & Pacific (excluding high income)
# EAR   Early-demographic dividend
# EAS   East Asia & Pacific
# ECA   Europe & Central Asia (excluding high income)
# ECS   Europe & Central Asia
# ECU   Ecuador                                               LCN       UMC
# EGY   Egypt, Arab Rep.                                      MEA       LMC
# EMU   Euro area
# ERI   Eritrea                                               SSF       LIC
# ESP   Spain                                                 ECS       HIC
# EST   Estonia                                               ECS       HIC
# ETH   Ethiopia                                              SSF       LIC
# EUU   European Union
# FCS   Fragile and conflict affected situations
# FIN   Finland                                               ECS       HIC
# FJI   Fiji                                                  EAS       UMC
# FRA   France                                                ECS       HIC
# FRO   Faroe Islands                                         ECS       HIC
# FSM   Micronesia, Fed. Sts.                                 EAS       LMC
# GAB   Gabon                                                 SSF       UMC
# GBR   United Kingdom                                        ECS       HIC
# GEO   Georgia                                               ECS       UMC
# GHA   Ghana                                                 SSF       LMC
# GIB   Gibraltar                                             ECS       HIC
# GIN   Guinea                                                SSF       LMC
# GMB   Gambia, The                                           SSF       LIC
# GNB   Guinea-Bissau                                         SSF       LIC
# GNQ   Equatorial Guinea                                     SSF       UMC
# GRC   Greece                                                ECS       HIC
# GRD   Grenada                                               LCN       UMC
# GRL   Greenland                                             ECS       HIC
# GTM   Guatemala                                             LCN       UMC
# GUM   Guam                                                  EAS       HIC
# GUY   Guyana                                                LCN       HIC
# HIC   High income
# HKG   Hong Kong SAR, China                                  EAS       HIC
# HND   Honduras                                              LCN       LMC
# HPC   Heavily indebted poor countries (HIPC)
# HRV   Croatia                                               ECS       HIC
# HTI   Haiti                                                 LCN       LMC
# HUN   Hungary                                               ECS       HIC
# IBD   IBRD only
# IBT   IDA & IBRD total
# IDA   IDA total
# IDB   IDA blend
# IDN   Indonesia                                             EAS       UMC
# IDX   IDA only
# IMN   Isle of Man                                           ECS       HIC
# IND   India                                                 SAS       LMC
# INX   Not classified
# IRL   Ireland                                               ECS       HIC
# IRN   Iran, Islamic Rep.                                    MEA       LMC
# IRQ   Iraq                                                  MEA       UMC
# ISL   Iceland                                               ECS       HIC
# ISR   Israel                                                MEA       HIC
# ITA   Italy                                                 ECS       HIC
# JAM   Jamaica                                               LCN       UMC
# JOR   Jordan                                                MEA       LMC
# JPN   Japan                                                 EAS       HIC
# KAZ   Kazakhstan                                            ECS       UMC
# KEN   Kenya                                                 SSF       LMC
# KGZ   Kyrgyz Republic                                       ECS       LMC
# KHM   Cambodia                                              EAS       LMC
# KIR   Kiribati                                              EAS       LMC
# KNA   St. Kitts and Nevis                                   LCN       HIC
# KOR   Korea, Rep.                                           EAS       HIC
# KWT   Kuwait                                                MEA       HIC
# LAC   Latin America & Caribbean (excluding high income)
# LAO   Lao PDR                                               EAS       LMC
# LBN   Lebanon                                               MEA       LMC
# LBR   Liberia                                               SSF       LIC
# LBY   Libya                                                 MEA       UMC
# LCA   St. Lucia                                             LCN       UMC
# LCN   Latin America & Caribbean
# LDC   Least developed countries: UN classification
# LIC   Low income
# LIE   Liechtenstein                                         ECS       HIC
# LKA   Sri Lanka                                             SAS       LMC
# LMC   Lower middle income
# LMY   Low & middle income
# LSO   Lesotho                                               SSF       LMC
# LTE   Late-demographic dividend
# LTU   Lithuania                                             ECS       HIC
# LUX   Luxembourg                                            ECS       HIC
# LVA   Latvia                                                ECS       HIC
# MAC   Macao SAR, China                                      EAS       HIC
# MAF   St. Martin (French part)                              LCN       HIC
# MAR   Morocco                                               MEA       LMC
# MCO   Monaco                                                ECS       HIC
# MDA   Moldova                                               ECS       UMC
# MDG   Madagascar                                            SSF       LIC
# MDV   Maldives                                              SAS       UMC
# MEA   Middle East & North Africa
# MEX   Mexico                                                LCN       UMC
# MHL   Marshall Islands                                      EAS       UMC
# MIC   Middle income
# MKD   North Macedonia                                       ECS       UMC
# MLI   Mali                                                  SSF       LIC
# MLT   Malta                                                 MEA       HIC
# MMR   Myanmar                                               EAS       LMC
# MNA   Middle East & North Africa (excluding high income)
# MNE   Montenegro                                            ECS       UMC
# MNG   Mongolia                                              EAS       LMC
# MNP   Northern Mariana Islands                              EAS       HIC
# MOZ   Mozambique                                            SSF       LIC
# MRT   Mauritania                                            SSF       LMC
# MUS   Mauritius                                             SSF       UMC
# MWI   Malawi                                                SSF       LIC
# MYS   Malaysia                                              EAS       UMC
# NAC   North America
# NAM   Namibia                                               SSF       UMC
# NCL   New Caledonia                                         EAS       HIC
# NER   Niger                                                 SSF       LIC
# NGA   Nigeria                                               SSF       LMC
# NIC   Nicaragua                                             LCN       LMC
# NLD   Netherlands                                           ECS       HIC
# NOR   Norway                                                ECS       HIC
# NPL   Nepal                                                 SAS       LMC
# NRU   Nauru                                                 EAS       HIC
# NZL   New Zealand                                           EAS       HIC
# OED   OECD members
# OMN   Oman                                                  MEA       HIC
# OSS   Other small states
# PAK   Pakistan                                              SAS       LMC
# PAN   Panama                                                LCN       HIC
# PER   Peru                                                  LCN       UMC
# PHL   Philippines                                           EAS       LMC
# PLW   Palau                                                 EAS       UMC
# PNG   Papua New Guinea                                      EAS       LMC
# POL   Poland                                                ECS       HIC
# PRE   Pre-demographic dividend
# PRI   Puerto Rico                                           LCN       HIC
# PRK   Korea, Dem. People's Rep.                             EAS       LIC
# PRT   Portugal                                              ECS       HIC
# PRY   Paraguay                                              LCN       UMC
# PSE   West Bank and Gaza                                    MEA       UMC
# PSS   Pacific island small states
# PST   Post-demographic dividend
# PYF   French Polynesia                                      EAS       HIC
# QAT   Qatar                                                 MEA       HIC
# ROU   Romania                                               ECS       HIC
# RUS   Russian Federation                                    ECS       UMC
# RWA   Rwanda                                                SSF       LIC
# SAS   South Asia
# SAU   Saudi Arabia                                          MEA       HIC
# SDN   Sudan                                                 SSF       LIC
# SEN   Senegal                                               SSF       LMC
# SGP   Singapore                                             EAS       HIC
# SLB   Solomon Islands                                       EAS       LMC
# SLE   Sierra Leone                                          SSF       LIC
# SLV   El Salvador                                           LCN       UMC
# SMR   San Marino                                            ECS       HIC
# SOM   Somalia                                               SSF       LIC
# SRB   Serbia                                                ECS       UMC
# SSA   Sub-Saharan Africa (excluding high income)
# SSD   South Sudan                                           SSF       LIC
# SSF   Sub-Saharan Africa
# SST   Small states
# STP   Sao Tome and Principe                                 SSF       LMC
# SUR   Suriname                                              LCN       UMC
# SVK   Slovak Republic                                       ECS       HIC
# SVN   Slovenia                                              ECS       HIC
# SWE   Sweden                                                ECS       HIC
# SWZ   Eswatini                                              SSF       LMC
# SXM   Sint Maarten (Dutch part)                             LCN       HIC
# SYC   Seychelles                                            SSF       HIC
# SYR   Syrian Arab Republic                                  MEA       LIC
# TCA   Turks and Caicos Islands                              LCN       HIC
# TCD   Chad                                                  SSF       LIC
# TEA   East Asia & Pacific (IDA & IBRD countries)
# TEC   Europe & Central Asia (IDA & IBRD countries)
# TGO   Togo                                                  SSF       LIC
# THA   Thailand                                              EAS       UMC
# TJK   Tajikistan                                            ECS       LMC
# TKM   Turkmenistan                                          ECS       UMC
# TLA   Latin America & the Caribbean (IDA & IBRD countries)
# TLS   Timor-Leste                                           EAS       LMC
# TMN   Middle East & North Africa (IDA & IBRD countries)
# TON   Tonga                                                 EAS       UMC
# TSA   South Asia (IDA & IBRD)
# TSS   Sub-Saharan Africa (IDA & IBRD countries)
# TTO   Trinidad and Tobago                                   LCN       HIC
# TUN   Tunisia                                               MEA       LMC
# TUR   Turkiye                                               ECS       UMC
# TUV   Tuvalu                                                EAS       UMC
# TZA   Tanzania                                              SSF       LMC
# UGA   Uganda                                                SSF       LIC
# UKR   Ukraine                                               ECS       LMC
# UMC   Upper middle income
# URY   Uruguay                                               LCN       HIC
# USA   United States                                         NAC       HIC
# UZB   Uzbekistan                                            ECS       LMC
# VCT   St. Vincent and the Grenadines                        LCN       UMC
# VEN   Venezuela, RB                                         LCN       INX
# VGB   British Virgin Islands                                LCN       HIC
# VIR   Virgin Islands (U.S.)                                 LCN       HIC
# VNM   Viet Nam                                              EAS       LMC
# VUT   Vanuatu                                               EAS       LMC
# WLD   World
# WSM   Samoa                                                 EAS       LMC
# XKX   Kosovo                                                ECS       UMC
# YEM   Yemen, Rep.                                           MEA       LIC
# ZAF   South Africa                                          SSF       UMC
# ZMB   Zambia                                                SSF       LMC
# ZWE   Zimbabwe                                              SSF       LMC
#       266 elements

# %%
df_country = wb.economy.DataFrame()

table = wb.economy.info()
table_dict = vars(table)
df_source = pd.DataFrame(table_dict.get('items')) # pour avoir la liste des pays et les id

type(df_source)
print((df_country))
df = pd.DataFrame(df_source, columns=['id', 'value']) 

lis_country = []
type(lis_country)
for index, row in df.iterrows():
    # print(row["id"], row["value"])
    lis_country.append((row["id"], row["value"]))
    
code_country = ''
country = ''
# lis_country[0][0] #y[lis_country.index('TGO')]
def check_code_country(code_input_country : str) -> True:
    # [T for item in lis_country if 'TGO' in item]
    if any(code_input_country in code for code in lis_country):
        global code_country, country
        for i in range(len(lis_country)):
            if lis_country[i][0] == value_input_country:
                print(f"Vous avez choisi ce pays:  {lis_country[i][1]} - {code_input_country}") 
                code_country, country = code_input_country, lis_country[i][1]
                return True
    return False
# les id doivent figurer dans la liste des id. sinon retourner une erreur
# Out:
#                             name  aggregate  longitude  latitude region  \
# id
# ABW                        Aruba      False   -70.0167  12.51670    LCN
# AFE  Africa Eastern and Southern       True        NaN       NaN
# AFG                  Afghanistan      False    69.1761  34.52280    SAS
# AFW   Africa Western and Central       True        NaN       NaN
# AGO                       Angola      False    13.2420  -8.81155    SSF
# ..                           ...        ...        ...       ...    ...
# XKX                       Kosovo      False    20.9260  42.56500    ECS
# YEM                  Yemen, Rep.      False    44.2075  15.35200    MEA
# ZAF                 South Africa      False    28.1871 -25.74600    SSF
# ZMB                       Zambia      False    28.2937 -15.39820    SSF
# ZWE                     Zimbabwe      False    31.0672 -17.83120    SSF
#
#     adminregion lendingType incomeLevel capitalCity
# id
# ABW                     LNX         HIC  Oranjestad
# AFE
# AFG         SAS         IDX         LIC       Kabul
# AFW
# AGO         SSA         IBD         LMC      Luanda
# ..          ...         ...         ...         ...
# XKX         ECA         IDX         UMC    Pristina
# YEM         MNA         IDX         LIC      Sana'a
# ZAF         SSA         IBD         UMC    Pretoria
# ZMB         SSA         IDX         LMC      Lusaka
# ZWE         SSA         IDB         LMC      Harare
#
# [266 rows x 9 columns]

# %% [markdown]
# ## Enter country code:
# - Example: TGO, CAN, FRA, USA

# %%
value_input_country = str(input("Please, enter country code: ")).upper()


check_code_country(value_input_country)
print(code_country, country)
# Out:
# Please, enter country code: tgo
# Vous avez choisi ce pays:  Togo - TGO
# TGO Togo

# %%
gdp_indicator = wb.data.DataFrame('NY.GNP.PCAP.PP.KD', code_country, range(1990, 2022))  # PIB par habitant

gdp_indicator
# Out:
#               YR1990      YR1991       YR1992       YR1993       YR1994  \
# economy
# TGO      1770.551265  1706.92941  1596.078634  1360.947396  1519.183636
#
#               YR1995       YR1996       YR1997      YR1998       YR1999  ...  \
# economy                                                                  ...
# TGO      1591.263266  1687.544386  1870.257074  1778.35937  1754.589802  ...
#
#               YR2012       YR2013       YR2014       YR2015       YR2016  \
# economy
# TGO      1749.779178  1810.415963  1870.217408  1956.667097  1960.849843
#
#               YR2017       YR2018       YR2019       YR2020       YR2021
# economy
# TGO      1972.566518  2013.847742  2060.479039  2070.396557  2133.438363
#
# [1 rows x 32 columns]

# %%
wb.data.DataFrame(['NY.GDP.PCAP.PP.KD'],
                     code_country,
                      time=range(1990,2022,5)).plot.bar()
# Out:
# <Axes: xlabel='economy'>

# %%
life_expectancy_indicator = wb.data.DataFrame('SP.DYN.LE00.IN', code_country, range(1990, 2022))  #Espérance de vie à la naissance, total (années)
life_expectancy_indicator
# Out:
#          YR1990  YR1991  YR1992  YR1993  YR1994  YR1995  YR1996  YR1997  \
# economy
# TGO       54.37  54.268  54.299  54.195  54.037  54.037  54.098  54.192
#
#          YR1998  YR1999  ...  YR2012  YR2013  YR2014  YR2015  YR2016  YR2017  \
# economy                  ...
# TGO      54.199  54.538  ...  58.073  58.684  58.853  59.396   59.55  60.154
#
#          YR2018  YR2019  YR2020  YR2021
# economy
# TGO      60.244  60.901  61.035  61.619
#
# [1 rows x 32 columns]

# %% [markdown]
# # rapport sur l'Espérance de vie

# %%
wb.data.DataFrame(['SP.DYN.LE00.IN'],
                     code_country,
                      time=range(1990,2022,5)).plot.bar() #graphique en barre pour l'indicateur choisi
# Out:
# <Axes: xlabel='economy'>

# %%
co2_emissions_indicator = wb.data.DataFrame('EN.ATM.CO2E.PC', code_country, range(1990, 2022), numericTimeKeys=True,)  #Émissions de CO2 (tonnes métriques par habitant)
co2_emissions_indicator
# Out:
#              1990      1991      1992      1993      1994      1995      1996  \
# economy
# TGO      0.252222  0.231942  0.181676  0.155233  0.221594  0.228388  0.305136
#
#              1997      1998      1999  ...      2012      2013     2014  \
# economy                                ...
# TGO      0.166291  0.253707  0.350908  ...  0.322783  0.246122  0.21795
#
#              2015      2016      2017     2018      2019      2020  2021
# economy
# TGO      0.244285  0.300939  0.257068  0.27215  0.296284  0.286062   NaN
#
# [1 rows x 32 columns]

# %%
wb.data.DataFrame(['EN.ATM.CO2E.PC'],
                     code_country,
                      time=range(1990,2021,5)).plot.bar()
# Out:
# <Axes: xlabel='economy'>

# %%
list_values_gdp = []

gdp=wb.data.DataFrame('NY.GDP.PCAP.PP.KD', 
                    economy = code_country,
                      
                    time = range(1990, 2022), numericTimeKeys = True,
                    labels = True).set_index('Country')

for (column_name, column_data) in gdp.items():

    list_values_gdp.append(column_data.values)
    
list_values_gdp    #pour afficher la liste des valeurs du dataframe du pays choisi
# Out:
# [array([1800.32017413]),
#  array([1736.52352747]),
#  array([1620.2926265]),
#  array([1385.08246528]),
#  array([1587.06768079]),
#  array([1636.81523647]),
#  array([1714.80513216]),
#  array([1898.7117835]),
#  array([1801.78639414]),
#  array([1793.53263883]),
#  array([1729.70175791]),
#  array([1697.37871238]),
#  array([1716.91346228]),
#  array([1785.15463371]),
#  array([1721.87620122]),
#  array([1599.45858532]),
#  array([1596.38773547]),
#  array([1532.42006065]),
#  array([1549.44041224]),
#  array([1588.96477697]),
#  array([1637.65195835]),
#  array([1687.61106815]),
#  array([1747.88421246]),
#  array([1802.93897953]),
#  array([1856.90481374]),
#  array([1910.00004506]),
#  array([1941.62759622]),
#  array([1970.21483978]),
#  array([2014.94172914]),
#  array([2063.75873637]),
#  array([2058.56505955]),
#  array([2130.85891737])]

# %%
import matplotlib.pyplot as plt
import numpy as np

years=np.arange(1990, 2022)
fig, ax1=plt.subplots()

ax1.set_xlabel('Year')
ax1.set_ylabel(f'GDP per capita in {country}', color='tab:blue')
ax1.plot(years, list_values_gdp, color='tab:blue', label=f'GDP per cap in {country}')
ax1.tick_params(axis='y', labelcolor='tab:blue')

plt.title(f'GDP per capita in {country}')
fig.tight_layout()
plt.show()

#évolution en courbe du PIB du pays choisi

# %%
list_values_life_expectancy = []

life_expectancy=wb.data.DataFrame('SP.DYN.LE00.IN', 
                    economy = code_country, 
                    time = range(1990, 2022), numericTimeKeys = True,
                    labels = True).set_index('Country')


for (column_name, column_data) in life_expectancy.items():

    list_values_life_expectancy.append(column_data.values)
    
list_values_life_expectancy
# Out:
# [array([54.37]),
#  array([54.268]),
#  array([54.299]),
#  array([54.195]),
#  array([54.037]),
#  array([54.037]),
#  array([54.098]),
#  array([54.192]),
#  array([54.199]),
#  array([54.538]),
#  array([54.742]),
#  array([54.86]),
#  array([55.311]),
#  array([55.639]),
#  array([55.569]),
#  array([55.962]),
#  array([56.222]),
#  array([56.511]),
#  array([56.695]),
#  array([57.011]),
#  array([57.304]),
#  array([57.925]),
#  array([58.073]),
#  array([58.684]),
#  array([58.853]),
#  array([59.396]),
#  array([59.55]),
#  array([60.154]),
#  array([60.244]),
#  array([60.901]),
#  array([61.035]),
#  array([61.619])]

# %%
import matplotlib.pyplot as plt
import numpy as np

years=np.arange(1990, 2022)
fig, ax1=plt.subplots()

ax1.set_xlabel('Year')
ax1.set_ylabel(f'Life expectancy at birth in {country}', color='tab:blue')
ax1.plot(years, list_values_life_expectancy, color='tab:blue', label= f'Life expectancy at birth in {country}')
ax1.tick_params(axis='y', labelcolor='tab:blue')

plt.title(f'Life expectancy at birth in {country}')
fig.tight_layout()
plt.show()

# %%
list_values_CO2_emissions = []

CO2_emissions=wb.data.DataFrame('EN.ATM.CO2E.PC', 
                    economy = code_country, 
                    time = range(1990, 2022), numericTimeKeys = True,
                    labels = True).set_index('Country')


for (column_name, column_data) in CO2_emissions.items():

    list_values_CO2_emissions.append(column_data.values)

list_values_CO2_emissions
# Out:
# [array([0.25222223]),
#  array([0.23194239]),
#  array([0.18167565]),
#  array([0.15523275]),
#  array([0.22159442]),
#  array([0.22838764]),
#  array([0.30513624]),
#  array([0.16629106]),
#  array([0.25370657]),
#  array([0.35090811]),
#  array([0.2533928]),
#  array([0.22896063]),
#  array([0.2545092]),
#  array([0.33827701]),
#  array([0.31952028]),
#  array([0.30606151]),
#  array([0.26720052]),
#  array([0.24864668]),
#  array([0.25211805]),
#  array([0.44145429]),
#  array([0.40020664]),
#  array([0.37275482]),
#  array([0.322783]),
#  array([0.2461221]),
#  array([0.21794958]),
#  array([0.2442853]),
#  array([0.30093897]),
#  array([0.25706771]),
#  array([0.27214954]),
#  array([0.29628438]),
#  array([0.28606184]),
#  array([nan])]

# %%
import matplotlib.pyplot as plt
import numpy as np

years=np.arange(1990, 2022)
fig, ax1=plt.subplots()

ax1.set_xlabel('Year')
ax1.set_ylabel(f'Émissions de CO2 in {country}', color='tab:blue')
ax1.plot(years, list_values_CO2_emissions, color='tab:blue', label=f'Émissions de CO2 in {country}')
ax1.tick_params(axis='y', labelcolor='tab:blue')

plt.title(f'Émissions de CO2 in {country}')
fig.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

years=np.arange(1990, 2022)
fig, ax1=plt.subplots()

ax1.set_xlabel('Year')
ax1.set_ylabel(f'GDP per capita in {country}', color='tab:blue')
ax1.plot(years, list_values_gdp, color='tab:blue', label=f'GDP per capita in {country}')
ax1.tick_params(axis='y', labelcolor='tab:blue')

ax2=ax1.twinx()
ax2.set_ylabel(f'Émissions de CO2 in {country}', color='tab:red')
ax2.plot(years, list_values_CO2_emissions, color='tab:red', label=f'Émissions de CO2 in {country}')
ax2.tick_params(axis='y', labelcolor='tab:red')

plt.title(f'GDP and CO2 in {country}')
fig.tight_layout()
plt.show()

#évolution du PIB et de l'émission du CO2

# %%
import matplotlib.pyplot as plt
import numpy as np

years=np.arange(1990, 2022)
fig, ax1=plt.subplots()

ax1.set_xlabel('Year')
ax1.set_ylabel(f'GDP per capita in {country}', color='tab:blue')
ax1.plot(years, list_values_gdp, color='tab:green', label=f'GDP per capita in {country}')
ax1.tick_params(axis='y', labelcolor='tab:green')

ax2=ax1.twinx()
ax2.set_ylabel(f'Life expectancy at birth in {country}', color='tab:red')
ax2.plot(years, list_values_life_expectancy, color='tab:red', label=f'Life expectancy at birth in {country}')
ax2.tick_params(axis='y', labelcolor='tab:red')

plt.title(f'GDP and Life expectancy in {country}')
fig.tight_layout()
plt.show()
#évolution du PIB et de l'espérance de vie

# %%
import matplotlib.pyplot as plt
import numpy as np

years=np.arange(1990, 2022)
fig, ax1=plt.subplots()

ax1.set_xlabel('Year')
ax1.set_ylabel(f'Life expectancy at birth in {country}', color='tab:blue')
ax1.plot(years, list_values_life_expectancy, color='tab:blue', label=f'Life expectancy at birth in {country}')
ax1.tick_params(axis='y', labelcolor='tab:blue')

ax2=ax1.twinx()
ax2.set_ylabel(f'Émissions de CO2 in {country}', color='tab:red')
ax2.plot(years, list_values_CO2_emissions, color='tab:green', label=f'Émissions de CO2 in {country}')
ax2.tick_params(axis='y', labelcolor='tab:red')

plt.title(f'Life expectancy and Émissions de CO2 in {country}')
fig.tight_layout()
plt.show() #évolution de l'émission du CO2 et de l'espérance de vie

# %%
import matplotlib.pyplot as plt
import numpy as np

years=np.arange(1990, 2022)
fig, ax1=plt.subplots(figsize=(12, 6))

ax1.set_xlabel('Year')
ax1.set_ylabel(f'GDP per capita in {country}', color='tab:green')
ax1.plot(years, list_values_gdp, color='tab:green', label=f'GDP per capita in {country}')
ax1.tick_params(axis='y', labelcolor='tab:green')

ax2=ax1.twinx()
ax2.set_xlabel('Year')
ax2.set_ylabel(f'Life expectancy at birth in {country}', color='tab:blue')
ax2.plot(years, list_values_life_expectancy, color='tab:blue', label=f'Life expectancy at birth in {country}')
ax2.tick_params(axis='y', labelcolor='tab:blue')

ax3=ax1.twinx()
ax3.spines['right'].set_position(('outward', 60))
ax3.set_ylabel(f'Émissions de CO2 in {country}', color='tab:red')
ax3.plot(years, list_values_CO2_emissions, color='tab:red', label=f'Émissions de CO2 in {country}')
ax3.tick_params(axis='y', labelcolor='tab:red')

plt.title(f'GDP and CO2 and life expectancy in {country}')
fig.tight_layout()
plt.show()

#évolution du PIB, du CO2 et de l'espérance de vie

# %%
#QUESTION 2 : Analyse Temporelle des Tendances Économiques

# PIB par habitant, ($ PPA internationaux courants). NY.GDP.PCAP.PP.CD
# Inflation, prix à la consommation (% annuel). FP.CPI.TOTL.ZG
# Chômage (% de la population active) (estimation nationale). SL.UEM.TOTL.NE.ZS

# %%
PIB_indicator = wb.data.DataFrame('NY.GDP.PCAP.PP.CD', code_country, range(1990, 2022))  # PIB par habitant, ($ PPA internationaux courants)

PIB_indicator
# Out:
#               YR1990       YR1991       YR1992      YR1993       YR1994  \
# economy
# TGO      1145.240353  1142.014173  1089.859139  953.732736  1116.150868
#
#               YR1995       YR1996       YR1997       YR1998       YR1999  ...  \
# economy                                                                   ...
# TGO      1175.275469  1253.818456  1412.225991  1355.218375  1368.020987  ...
#
#               YR2012      YR2013       YR2014      YR2015       YR2016  \
# economy
# TGO      1677.296286  1739.13225  1818.041895  1884.96673  1928.141125
#
#              YR2017       YR2018       YR2019       YR2020       YR2021
# economy
# TGO      1970.21484  2063.382109  2151.285143  2173.872929  2351.313774
#
# [1 rows x 32 columns]

# %%
wb.data.DataFrame(['NY.GDP.PCAP.PP.CD'],
                     code_country,
                      time=range(1990,2022,5)).plot.bar()
# Out:
# <Axes: xlabel='economy'>

# %%
Inflation_indicator = wb.data.DataFrame('FP.CPI.TOTL.ZG', code_country, range(1990, 2022))  # Inflation, prix à la consommation (% annuel). 

Inflation_indicator
# Out:
#            YR1990    YR1991    YR1992    YR1993     YR1994     YR1995  YR1996  \
# economy
# TGO      1.015342  0.387082  1.393787 -1.006882  39.162767  16.433503  4.6875
#
#            YR1997    YR1998    YR1999  ...    YR2012    YR2013    YR2014  \
# economy                                ...
# TGO      8.250825  0.975338 -0.053214  ...  2.577182  1.825395  0.190875
#
#            YR2015    YR2016   YR2017    YR2018    YR2019    YR2020    YR2021
# economy
# TGO      2.585004  1.285448 -0.98189  0.927755  0.674653  1.699285  4.186215
#
# [1 rows x 32 columns]

# %%
wb.data.DataFrame(['FP.CPI.TOTL.ZG'],
                     code_country,
                      time=range(1990,2022,5)).plot.bar()
# Out:
# <Axes: xlabel='economy'>

# %%
Chomage_indicator = wb.data.DataFrame('SL.UEM.TOTL.NE.ZS', code_country, range(1990, 2022))  # Chômage (% de la population active) (estimation nationale).

Chomage_indicator
# Out:
#          YR1990  YR1991  YR1992  YR1993  YR1994  YR1995  YR1996  YR1997  \
# economy
# TGO         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#          YR1998  YR1999  ...  YR2012  YR2013  YR2014  YR2015  YR2016  YR2017  \
# economy                  ...
# TGO         NaN     NaN  ...     NaN     NaN     NaN   2.204     NaN   3.744
#
#          YR2018  YR2019  YR2020  YR2021
# economy
# TGO         NaN   2.056     NaN     NaN
#
# [1 rows x 32 columns]

# %%
wb.data.DataFrame(['SL.UEM.TOTL.NE.ZS'],
                     code_country,
                      time=range(1990,2022)).plot.bar()
# Out:
# <Axes: xlabel='economy'>

# %%
list_values_PIB = []

PIB=wb.data.DataFrame('NY.GDP.PCAP.PP.CD', 
                    economy = code_country,
                      
                    time = range(1990, 2022), numericTimeKeys = True,
                    labels = True).set_index('Country')

for (column_name, column_data) in PIB.items():

    list_values_PIB.append(column_data.values)
    
list_values_PIB
# Out:
# [array([1145.24035338]),
#  array([1142.01417336]),
#  array([1089.8591387]),
#  array([953.73273631]),
#  array([1116.15086753]),
#  array([1175.2754686]),
#  array([1253.8184564]),
#  array([1412.22599095]),
#  array([1355.21837545]),
#  array([1368.02098659]),
#  array([1349.22397812]),
#  array([1353.8402806]),
#  array([1390.76418512]),
#  array([1474.58116569]),
#  array([1460.49228876]),
#  array([1399.20029226]),
#  array([1439.60451977]),
#  array([1419.26592274]),
#  array([1462.5523927]),
#  array([1509.47377425]),
#  array([1574.42186245]),
#  array([1656.1619505]),
#  array([1677.29628559]),
#  array([1739.13224968]),
#  array([1818.04189531]),
#  array([1884.96673035]),
#  array([1928.14112525]),
#  array([1970.21483978]),
#  array([2063.38210892]),
#  array([2151.28514317]),
#  array([2173.87292875]),
#  array([2351.3137741])]

# %%
list_values_Inflation = []

Inflation=wb.data.DataFrame('FP.CPI.TOTL.ZG', 
                    economy = code_country,
                      
                    time = range(1990, 2022), numericTimeKeys = True,
                    labels = True).set_index('Country')

for (column_name, column_data) in Inflation.items():

    list_values_Inflation.append(column_data.values)
    
list_values_Inflation
# Out:
# [array([1.01534151]),
#  array([0.3870818]),
#  array([1.39378664]),
#  array([-1.00688169]),
#  array([39.16276738]),
#  array([16.43350345]),
#  array([4.6875]),
#  array([8.25082508]),
#  array([0.97533838]),
#  array([-0.05321362]),
#  array([1.86260595]),
#  array([3.91959134]),
#  array([3.05981858]),
#  array([-0.93000088]),
#  array([0.39307868]),
#  array([6.78292893]),
#  array([2.22897779]),
#  array([0.94567327]),
#  array([8.69482814]),
#  array([3.71360592]),
#  array([1.44594517]),
#  array([3.56351473]),
#  array([2.57718174]),
#  array([1.82539476]),
#  array([0.19087508]),
#  array([2.58500391]),
#  array([1.28544847]),
#  array([-0.98188987]),
#  array([0.92775543]),
#  array([0.67465277]),
#  array([1.69928463]),
#  array([4.18621507])]

# %%
list_values_Chomage = []

Chomage=wb.data.DataFrame('SL.UEM.TOTL.NE.ZS', 
                    economy = code_country,
                      
                    time = range(1990, 2022), numericTimeKeys = True,
                    labels = True).set_index('Country')

for (column_name, column_data) in Chomage.items():

    list_values_Chomage.append(column_data.values)
    
list_values_Chomage 

# les données sur le chômage du Togo sont manquantes
# Out:
# [array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([4.229]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([1.982]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([2.204]),
#  array([nan]),
#  array([3.744]),
#  array([nan]),
#  array([2.056]),
#  array([nan]),
#  array([nan])]

# %%
import matplotlib.pyplot as plt
import numpy as np

years=np.arange(1990, 2022)
fig, ax1=plt.subplots()

ax1.set_xlabel('Year')
ax1.set_ylabel('PIB par habitant, ($ PPA internationaux courants)', color='tab:blue')
ax1.plot(years, list_values_PIB, color='tab:blue', label='PIB par habitant, ($ PPA internationaux courants)')
ax1.tick_params(axis='y', labelcolor='tab:blue')

plt.title('PIB par habitant, ($ PPA internationaux courants)')
fig.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

years=np.arange(1990, 2022)
fig, ax1=plt.subplots()

ax1.set_xlabel('Year')
ax1.set_ylabel('Inflation au Togo', color='tab:blue')
ax1.plot(years, list_values_Inflation, color='tab:blue', label='Inflation au Togo')
ax1.tick_params(axis='y', labelcolor='tab:blue')

plt.title('Inflation au Togo')
fig.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

years=np.arange(1990, 2022)
fig, ax1=plt.subplots(figsize=(12, 6))

ax1.set_xlabel('Year')
ax1.set_ylabel('PIB par habitant, ($ PPA internationaux courants)', color='tab:green')
ax1.plot(years, list_values_PIB, color='tab:green', label='PIB par habitant, ($ PPA internationaux courants)')
ax1.tick_params(axis='y', labelcolor='tab:green')

ax2=ax1.twinx()
ax2.set_xlabel('Year')
ax2.set_ylabel('Inflation au Togo', color='tab:blue')
ax2.plot(years, list_values_Inflation, color='tab:blue', label='Inflation au Togo')
ax2.tick_params(axis='y', labelcolor='tab:blue')

ax3=ax1.twinx()
ax3.spines['right'].set_position(('outward', 40))
ax3.set_ylabel('Chômage au Togo', color='tab:red')
ax3.plot(years, list_values_Chomage, color='tab:red', label='Chômage au Togo')
ax3.tick_params(axis='y', labelcolor='tab:red')

plt.title('PIB par habitant et Inflation au Togo')
fig.tight_layout()
plt.show()

# %%
#QUESTION 3 : Analyse de Cluster

# PIB par habitant. NY.GDP.PCAP.PP.KD
# Pauvreté à $ 1,90 par jour (2011 PPA) (%). SI.POV.GAPS
# Indice du capital humain, limite supérieure (échelle comprise entre 0 et 1). HD.HCI.OVRL.UB
# Indice du capital humain, limite inférieure (échelle comprise entre 0 et 1). HD.HCI.OVRL.LB

# %%
PIB_HA = wb.data.DataFrame('NY.GDP.PCAP.PP.KD', code_country, range(1990, 2022)) # PIB par habitant
PIB_HA
# Out:
#               YR1990       YR1991       YR1992       YR1993       YR1994  \
# economy
# TGO      1800.320174  1736.523527  1620.292627  1385.082465  1587.067681
#
#               YR1995       YR1996       YR1997       YR1998       YR1999  ...  \
# economy                                                                   ...
# TGO      1636.815236  1714.805132  1898.711783  1801.786394  1793.532639  ...
#
#               YR2012      YR2013       YR2014       YR2015       YR2016  \
# economy
# TGO      1747.884212  1802.93898  1856.904814  1910.000045  1941.627596
#
#              YR2017       YR2018       YR2019      YR2020       YR2021
# economy
# TGO      1970.21484  2014.941729  2063.758736  2058.56506  2130.858917
#
# [1 rows x 32 columns]

# %%
Pauvrete_indic = wb.data.DataFrame('SI.POV.GAPS', code_country, range(1990, 2022))  # Pauvreté à $ 1,90 par jour (2011 PPA) (%)
Pauvrete_indic
# Out:
#          YR1990  YR1991  YR1992  YR1993  YR1994  YR1995  YR1996  YR1997  \
# economy
# TGO         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#          YR1998  YR1999  ...  YR2012  YR2013  YR2014  YR2015  YR2016  YR2017  \
# economy                  ...
# TGO         NaN     NaN  ...     NaN     NaN     NaN    23.5     NaN     NaN
#
#          YR2018  YR2019  YR2020  YR2021
# economy
# TGO         8.5     NaN     NaN     NaN
#
# [1 rows x 32 columns]

# %%
ICH_lim_sup_indicator = wb.data.DataFrame('HD.HCI.OVRL.UB', code_country, range(1990, 2022))  # Indice du capital humain, limite supérieure (échelle comprise entre 0 et 1)
ICH_lim_sup_indicator
# Out:
#          YR1990  YR1991  YR1992  YR1993  YR1994  YR1995  YR1996  YR1997  \
# economy
# TGO         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#          YR1998  YR1999  ...  YR2012  YR2013  YR2014  YR2015  YR2016  YR2017  \
# economy                  ...
# TGO         NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN   0.431
#
#            YR2018  YR2019    YR2020  YR2021
# economy
# TGO      0.440186     NaN  0.452463     NaN
#
# [1 rows x 32 columns]

# %%
ICH_lim_inf_indicator = wb.data.DataFrame('HD.HCI.OVRL.LB', code_country, range(1990, 2022))  # Indice du capital humain, limite inférieure (échelle comprise entre 0 et 1)
ICH_lim_inf_indicator
# Out:
#          YR1990  YR1991  YR1992  YR1993  YR1994  YR1995  YR1996  YR1997  \
# economy
# TGO         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#          YR1998  YR1999  ...  YR2012  YR2013  YR2014  YR2015  YR2016  YR2017  \
# economy                  ...
# TGO         NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN   0.394
#
#            YR2018  YR2019    YR2020  YR2021
# economy
# TGO      0.400345     NaN  0.409654     NaN
#
# [1 rows x 32 columns]

# %%
wb.data.DataFrame(['NY.GDP.PCAP.PP.KD'],
                     code_country,
                      time=range(1990,2022,5)).plot.bar()
# Out:
# <Axes: xlabel='economy'>

# %%
wb.data.DataFrame(['SI.POV.GAPS'],
                     code_country,
                      time=range(1990,2022,5)).plot.bar()
# Out:
# <Axes: xlabel='economy'>

# %%
wb.data.DataFrame(['HD.HCI.OVRL.UB'],
                     code_country,
                      time=range(1990,2022,5)).plot.bar()
# Out:
# <Axes: xlabel='economy'>

# %%
wb.data.DataFrame(['HD.HCI.OVRL.LB'],
                     code_country,
                      time=range(1990,2022,5)).plot.bar()
# Out:
# <Axes: xlabel='economy'>

# %%
list_values_PIB_HA = []

PIB_HA=wb.data.DataFrame('NY.GDP.PCAP.PP.KD', 
                    economy = code_country,
                      
                    time = range(1990, 2022), numericTimeKeys = True,
                    labels = True).set_index('Country')

for (column_name, column_data) in PIB_HA.items():

    list_values_PIB_HA.append(column_data.values)
    
list_values_PIB_HA
# Out:
# [array([1800.32017413]),
#  array([1736.52352747]),
#  array([1620.2926265]),
#  array([1385.08246528]),
#  array([1587.06768079]),
#  array([1636.81523647]),
#  array([1714.80513216]),
#  array([1898.7117835]),
#  array([1801.78639414]),
#  array([1793.53263883]),
#  array([1729.70175791]),
#  array([1697.37871238]),
#  array([1716.91346228]),
#  array([1785.15463371]),
#  array([1721.87620122]),
#  array([1599.45858532]),
#  array([1596.38773547]),
#  array([1532.42006065]),
#  array([1549.44041224]),
#  array([1588.96477697]),
#  array([1637.65195835]),
#  array([1687.61106815]),
#  array([1747.88421246]),
#  array([1802.93897953]),
#  array([1856.90481374]),
#  array([1910.00004506]),
#  array([1941.62759622]),
#  array([1970.21483978]),
#  array([2014.94172914]),
#  array([2063.75873637]),
#  array([2058.56505955]),
#  array([2130.85891737])]

# %%
list_values_Pauvrete_indic = []

Pauvrete_indic=wb.data.DataFrame('SI.POV.GAPS', 
                    economy = code_country,
                      
                    time = range(1990, 2022), numericTimeKeys = True,
                    labels = True).set_index('Country')

for (column_name, column_data) in Pauvrete_indic.items():

    list_values_Pauvrete_indic.append(column_data.values)
    
list_values_Pauvrete_indic  

# Données manquantes
# Out:
# [array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([24.9]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([26.7]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([23.5]),
#  array([nan]),
#  array([nan]),
#  array([8.5]),
#  array([nan]),
#  array([nan]),
#  array([nan])]

# %%
list_values_ICH_lim_sup_indicator = []

ICH_lim_sup_indicator=wb.data.DataFrame('HD.HCI.OVRL.UB', 
                    economy = code_country,
                      
                    time = range(1990, 2022), numericTimeKeys = True,
                    labels = True).set_index('Country')

for (column_name, column_data) in ICH_lim_sup_indicator.items():

    list_values_ICH_lim_sup_indicator.append(column_data.values)
    
list_values_ICH_lim_sup_indicator  # Données manquantes
# Out:
# [array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([0.38080177]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([0.431]),
#  array([0.4401862]),
#  array([nan]),
#  array([0.45246288]),
#  array([nan])]

# %%
list_values_ICH_lim_inf_indicator = []

ICH_lim_inf_indicator=wb.data.DataFrame('HD.HCI.OVRL.LB', 
                    economy = code_country,
                      
                    time = range(1990, 2022), numericTimeKeys = True,
                    labels = True).set_index('Country')

for (column_name, column_data) in ICH_lim_inf_indicator.items():

    list_values_ICH_lim_inf_indicator.append(column_data.values)
    
list_values_ICH_lim_inf_indicator  # Données manquantes
# Out:
# [array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([0.35521924]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([0.394]),
#  array([0.40034521]),
#  array([nan]),
#  array([0.40965357]),
#  array([nan])]

# %%
import matplotlib.pyplot as plt
import numpy as np

years=np.arange(1990, 2022)
fig, ax1=plt.subplots()

ax1.set_xlabel('Year')
ax1.set_ylabel(f'GDP per cap in {country}', color='tab:blue')
ax1.plot(years, list_values_PIB_HA, color='tab:blue', label=f'GDP per cap in {country}')
ax1.tick_params(axis='y', labelcolor='tab:blue')

plt.title(f'GDP per cap in {country}')
fig.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

years=np.arange(1990, 2022)
fig, ax1=plt.subplots()

ax1.set_xlabel('Year')
ax1.set_ylabel(f'Indice de pauvreté in {country}', color='tab:blue')
ax1.plot(years, list_values_Pauvrete_indic , color='tab:blue', label=f'Indice de pauvreté in {country}')
ax1.tick_params(axis='y', labelcolor='tab:blue')

plt.title(f'Indice de pauvreté in {country}')
fig.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

years=np.arange(1990, 2022)
fig, ax1=plt.subplots()

ax1.set_xlabel('Year')
ax1.set_ylabel(f'ICH limite supérieure in {country}', color='tab:blue')
ax1.plot(years, list_values_ICH_lim_sup_indicator, color='tab:blue', label=f'ICH limite supérieure in {country}')
ax1.tick_params(axis='y', labelcolor='tab:blue')

plt.title(f'ICH limite supérieure in {country}')
fig.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

years=np.arange(1990, 2022)
fig, ax1=plt.subplots()

ax1.set_xlabel('Year')
ax1.set_ylabel(f'ICH limite inférieure in {country}', color='tab:blue')
ax1.plot(years, list_values_ICH_lim_inf_indicator, color='tab:blue', label=f'ICH limite inférieure in {country}')
ax1.tick_params(axis='y', labelcolor='tab:blue')

plt.title(f'ICH limite inférieure in {country}')
fig.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

years=np.arange(1990, 2022)
fig, ax1=plt.subplots(figsize=(12, 6))

ax1.set_xlabel('Year')
ax1.set_ylabel(f'GDP per capita in {country}', color='tab:green')
ax1.plot(years, list_values_gdp, color='tab:green', label=f'GDP per cap in {country}')
ax1.tick_params(axis='y', labelcolor='tab:green')

ax2=ax1.twinx()
ax2.set_xlabel('Year')
ax2.set_ylabel(f'ICH limite supérieure in {country}', color='tab:blue')
ax2.plot(years, list_values_ICH_lim_sup_indicator, color='tab:blue', label=f'ICH limite supérieure in {country}')
ax2.tick_params(axis='y', labelcolor='tab:blue')

ax3=ax1.twinx()
ax3.spines['right'].set_position(('outward', 60))
ax3.set_ylabel(f'ICH limite inférieure in {country}', color='tab:red')
ax3.plot(years, list_values_ICH_lim_inf_indicator, color='tab:red', label=f'ICH limite inférieure in {country}')
ax3.tick_params(axis='y', labelcolor='tab:red')

plt.title(f'GDP et ICH au Togo in {country}')
fig.tight_layout()
plt.show()

# %%
###QUESTION 4 : Prédictions des Tendances Futures

# Agriculture, valeur ajoutée (% de croissance annuelle). NV.AGR.TOTL.KD.ZG

# Industrie, valeur ajoutée (en $ US actuels). NV.IND.TOTL.CD
# Industrie, valeur ajoutée (% du PIB). NV.IND.TOTL.ZS

# Industrie, valeur ajoutée (% de croissance annuelle). NV.IND.TOTL.KD.ZG

# Inflation, prix à la consommation (% annuel). FP.CPI.TOTL.ZG

# %%
Agriculture = wb.data.DataFrame('NV.AGR.TOTL.KD.ZG', code_country, range(1990, 2022)) # PIB par habitant
Agriculture
# Out:
#            YR1990    YR1991    YR1992    YR1993    YR1994    YR1995  \
# economy
# TGO      2.991761 -1.138791  1.223445  5.994375 -0.062683  5.544884
#
#             YR1996    YR1997    YR1998    YR1999  ...    YR2012    YR2013  \
# economy                                           ...
# TGO      16.366716  4.463174 -2.761041  5.484821  ...  7.513952 -5.551212
#
#             YR2014   YR2015    YR2016    YR2017    YR2018    YR2019    YR2020  \
# economy
# TGO      15.469563 -0.65678  2.921729  6.806778  4.595203  5.554733 -0.910954
#
#            YR2021
# economy
# TGO      3.376311
#
# [1 rows x 32 columns]

# %%
Industrie_actu = wb.data.DataFrame('NV.IND.TOTL.CD', code_country, range(1990, 2022)) # PIB par habitant
Industrie_actu
# Out:
#                YR1990        YR1991        YR1992        YR1993        YR1994  \
# economy
# TGO      3.668604e+08  4.030677e+08  4.024681e+08  2.550478e+08  2.085883e+08
#
#                YR1995        YR1996        YR1997        YR1998        YR1999  \
# economy
# TGO      2.904307e+08  3.086305e+08  3.016381e+08  2.676490e+08  2.555756e+08
#
#          ...        YR2012        YR2013        YR2014        YR2015  \
# economy  ...
# TGO      ...  1.083545e+09  1.336735e+09  1.524658e+09  1.316068e+09
#
#                YR2016        YR2017        YR2018        YR2019        YR2020  \
# economy
# TGO      1.271902e+09  1.303138e+09  1.478227e+09  1.352688e+09  1.502816e+09
#
#                YR2021
# economy
# TGO      1.699330e+09
#
# [1 rows x 32 columns]

# %%
Industrie_PIB = wb.data.DataFrame('NV.IND.TOTL.ZS', code_country, range(1990, 2022)) # PIB par habitant
Industrie_PIB
# Out:
#             YR1990     YR1991     YR1992     YR1993     YR1994    YR1995  \
# economy
# TGO      22.528503  25.155572  23.773053  20.676811  21.227674  22.18073
#
#             YR1996     YR1997     YR1998    YR1999  ...     YR2012     YR2013  \
# economy                                             ...
# TGO      21.060487  20.123277  16.861414  16.20981  ...  20.015464  22.198525
#
#            YR2014     YR2015     YR2016     YR2017     YR2018    YR2019  \
# economy
# TGO      23.84769  22.866441  20.949867  20.401623  21.029758  19.34442
#
#             YR2020     YR2021
# economy
# TGO      20.074939  20.126824
#
# [1 rows x 32 columns]

# %%
Industrie_croissance_annuelle = wb.data.DataFrame('NV.IND.TOTL.KD.ZG', code_country, range(1990, 2022)) # PIB par habitant
Industrie_croissance_annuelle
# Out:
#            YR1990    YR1991    YR1992     YR1993     YR1994     YR1995  \
# economy
# TGO     -4.442643  7.082227 -7.689665 -29.377898  26.333455  20.752147
#
#           YR1996    YR1997    YR1998    YR1999  ...    YR2012     YR2013  \
# economy                                         ...
# TGO      5.22478  2.296416 -9.097167  2.788846  ... -3.035146  22.316106
#
#             YR2014    YR2015     YR2016    YR2017    YR2018    YR2019  \
# economy
# TGO      10.272512 -0.483294  16.185911  1.268879  8.272435 -1.359734
#
#            YR2020    YR2021
# economy
# TGO      5.539933  5.694836
#
# [1 rows x 32 columns]

# %%
Inflation_conso = wb.data.DataFrame('FP.CPI.TOTL.ZG', code_country, range(1990, 2022)) # PIB par habitant
Inflation_conso
# Out:
#            YR1990    YR1991    YR1992    YR1993     YR1994     YR1995  YR1996  \
# economy
# TGO      1.015342  0.387082  1.393787 -1.006882  39.162767  16.433503  4.6875
#
#            YR1997    YR1998    YR1999  ...    YR2012    YR2013    YR2014  \
# economy                                ...
# TGO      8.250825  0.975338 -0.053214  ...  2.577182  1.825395  0.190875
#
#            YR2015    YR2016   YR2017    YR2018    YR2019    YR2020    YR2021
# economy
# TGO      2.585004  1.285448 -0.98189  0.927755  0.674653  1.699285  4.186215
#
# [1 rows x 32 columns]

# %%
wb.data.DataFrame(['NV.AGR.TOTL.KD.ZG'],
                     code_country,
                      time=range(1990,2022,5)).plot.bar()
# Out:
# <Axes: xlabel='economy'>

# %%
wb.data.DataFrame(['NV.IND.TOTL.CD'],
                     code_country,
                      time=range(1990,2022,5)).plot.bar()
# Out:
# <Axes: xlabel='economy'>

# %%
wb.data.DataFrame(['NV.IND.TOTL.ZS'],
                     code_country,
                      time=range(1990,2022,5)).plot.bar()
# Out:
# <Axes: xlabel='economy'>

# %%
wb.data.DataFrame(['NV.IND.TOTL.KD.ZG'],
                     code_country,
                      time=range(1990,2022,5)).plot.bar()
# Out:
# <Axes: xlabel='economy'>

# %%
wb.data.DataFrame(['FP.CPI.TOTL.ZG'],
                     code_country,
                      time=range(1990,2022,5)).plot.bar()
# Out:
# <Axes: xlabel='economy'>

# %%
list_values_Agriculture = []

Agriculture=wb.data.DataFrame('NV.AGR.TOTL.KD.ZG', 
                    economy = code_country,
                      
                    time = range(1990, 2022), numericTimeKeys = True,
                    labels = True).set_index('Country')

for (column_name, column_data) in Agriculture.items():

    list_values_Agriculture.append(column_data.values)
    
list_values_Agriculture
# Out:
# [array([2.99176081]),
#  array([-1.138791]),
#  array([1.22344499]),
#  array([5.9943751]),
#  array([-0.06268331]),
#  array([5.54488437]),
#  array([16.36671595]),
#  array([4.46317431]),
#  array([-2.7610406]),
#  array([5.48482078]),
#  array([-4.73537901]),
#  array([5.59065174]),
#  array([0.31857666]),
#  array([-1.63006923]),
#  array([3.36749969]),
#  array([10.04718816]),
#  array([-5.25443527]),
#  array([2.11891476]),
#  array([-3.85245521]),
#  array([12.55552983]),
#  array([4.88581705]),
#  array([-0.596307]),
#  array([7.51395247]),
#  array([-5.5512121]),
#  array([15.46956253]),
#  array([-0.65677966]),
#  array([2.9217288]),
#  array([6.80677815]),
#  array([4.59520296]),
#  array([5.55473315]),
#  array([-0.91095447]),
#  array([3.37631069])]

# %%
import matplotlib.pyplot as plt
import numpy as np

years=np.arange(1990, 2022)
fig, ax1=plt.subplots()

ax1.set_xlabel('Year')
ax1.set_ylabel(f'Agriculture, valeur ajoutée (% de croissance annuelle) in {country}', color='tab:blue')
ax1.plot(years, list_values_Agriculture, color='tab:blue', label=f'Agriculture, valeur ajoutée (% de croissance annuelle) in {country}')
ax1.tick_params(axis='y', labelcolor='tab:blue')

plt.title(f'Agriculture, valeur ajoutée (% de croissance annuelle) in {country}')
fig.tight_layout()
plt.show()

# %%
list_values_Industrie_actu = []

Industrie_actu=wb.data.DataFrame('NV.IND.TOTL.CD', 
                    economy = code_country,
                      
                    time = range(1990, 2022), numericTimeKeys = True,
                    labels = True).set_index('Country')

for (column_name, column_data) in Industrie_actu.items():

    list_values_Industrie_actu.append(column_data.values)
    
list_values_Industrie_actu
# Out:
# [array([3.6686035e+08]),
#  array([4.03067688e+08]),
#  array([4.02468064e+08]),
#  array([2.55047826e+08]),
#  array([2.0858829e+08]),
#  array([2.90430662e+08]),
#  array([3.08630528e+08]),
#  array([3.01638054e+08]),
#  array([2.67648991e+08]),
#  array([2.55575646e+08]),
#  array([2.37688745e+08]),
#  array([2.28744847e+08]),
#  array([2.72506086e+08]),
#  array([3.0883737e+08]),
#  array([3.32741648e+08]),
#  array([3.63732958e+08]),
#  array([4.061869e+08]),
#  array([9.88434333e+08]),
#  array([1.09262098e+09]),
#  array([9.75678114e+08]),
#  array([9.652618e+08]),
#  array([1.18014774e+09]),
#  array([1.08354546e+09]),
#  array([1.33673517e+09]),
#  array([1.52465787e+09]),
#  array([1.31606834e+09]),
#  array([1.27190155e+09]),
#  array([1.30313821e+09]),
#  array([1.47822709e+09]),
#  array([1.35268835e+09]),
#  array([1.50281625e+09]),
#  array([1.69933034e+09])]

# %%
import matplotlib.pyplot as plt
import numpy as np

years=np.arange(1990, 2022)
fig, ax1=plt.subplots()

ax1.set_xlabel('Year')
ax1.set_ylabel(f'Industrie, valeur ajoutée (en $ US actuels) in {country}', color='tab:blue')
ax1.plot(years, list_values_Industrie_actu, color='tab:blue', label=f'Industrie, valeur ajoutée (en $ US actuels) in {country}')
ax1.tick_params(axis='y', labelcolor='tab:blue')

plt.title(f'Industrie, valeur ajoutée (en $ US actuels) in {country}')
fig.tight_layout()
plt.show()

# %%
list_values_Industrie_PIB = []

gdp=wb.data.DataFrame('NV.IND.TOTL.ZS', 
                    economy = code_country,
                      
                    time = range(1990, 2022), numericTimeKeys = True,
                    labels = True).set_index('Country')

for (column_name, column_data) in Industrie_PIB.items():

    list_values_Industrie_PIB.append(column_data.values)
    
list_values_Industrie_PIB
# Out:
# [array([22.52850254]),
#  array([25.15557231]),
#  array([23.77305296]),
#  array([20.67681067]),
#  array([21.22767402]),
#  array([22.18072958]),
#  array([21.06048699]),
#  array([20.12327685]),
#  array([16.86141444]),
#  array([16.20981015]),
#  array([15.93204331]),
#  array([15.43031703]),
#  array([15.96686003]),
#  array([14.59646836]),
#  array([14.7231306]),
#  array([15.94282998]),
#  array([17.27290262]),
#  array([26.28840688]),
#  array([23.86235987]),
#  array([20.66288013]),
#  array([20.3367703]),
#  array([21.76414903]),
#  array([20.01546356]),
#  array([22.19852528]),
#  array([23.84768999]),
#  array([22.86644053]),
#  array([20.94986725]),
#  array([20.40162301]),
#  array([21.02975832]),
#  array([19.34441978]),
#  array([20.0749387]),
#  array([20.12682423])]

# %%
import matplotlib.pyplot as plt
import numpy as np

years=np.arange(1990, 2022)
fig, ax1=plt.subplots()

ax1.set_xlabel('Year')
ax1.set_ylabel(f'Industrie, valeur ajoutée (% du PIB) in {country}', color='tab:blue')
ax1.plot(years, list_values_Industrie_PIB, color='tab:blue', label=f'Industrie, valeur ajoutée (% du PIB) in {country}')
ax1.tick_params(axis='y', labelcolor='tab:blue')

plt.title(f'Industrie, valeur ajoutée (% du PIB) in {country}')
fig.tight_layout()
plt.show()

# %%
list_values_Industrie_croissance_annuelle = []

Industrie_croissance_annuelle=wb.data.DataFrame('NV.IND.TOTL.KD.ZG', 
                    economy = code_country,
                      
                    time = range(1990, 2022), numericTimeKeys = True,
                    labels = True).set_index('Country')

for (column_name, column_data) in Industrie_croissance_annuelle.items():

    list_values_Industrie_croissance_annuelle.append(column_data.values)
    
list_values_Industrie_croissance_annuelle
# Out:
# [array([-4.44264315]),
#  array([7.08222702]),
#  array([-7.68966492]),
#  array([-29.37789797]),
#  array([26.3334554]),
#  array([20.75214728]),
#  array([5.22477996]),
#  array([2.29641588]),
#  array([-9.09716711]),
#  array([2.78884572]),
#  array([4.26357098]),
#  array([1.05031377]),
#  array([7.95434731]),
#  array([3.45794752]),
#  array([-3.74689788]),
#  array([5.06818138]),
#  array([7.90019345]),
#  array([-5.68652347]),
#  array([-2.09674288]),
#  array([2.68667135]),
#  array([8.78901134]),
#  array([8.60425761]),
#  array([-3.03514616]),
#  array([22.3161065]),
#  array([10.27251243]),
#  array([-0.48329446]),
#  array([16.18591099]),
#  array([1.26887929]),
#  array([8.27243463]),
#  array([-1.35973408]),
#  array([5.53993284]),
#  array([5.69483626])]

# %%
import matplotlib.pyplot as plt
import numpy as np

years=np.arange(1990, 2022)
fig, ax1=plt.subplots()

ax1.set_xlabel('Year')
ax1.set_ylabel(f'Industrie, valeur ajoutée (% de croissance annuelle) in {country}', color='tab:blue')
ax1.plot(years, list_values_Industrie_croissance_annuelle, color='tab:blue', label=f'Industrie, valeur ajoutée (% de croissance annuelle) in {country}')
ax1.tick_params(axis='y', labelcolor='tab:blue')

plt.title(f'Industrie, valeur ajoutée (% de croissance annuelle) in {country}')
fig.tight_layout()
plt.show()

# %%
list_values_Inflation_conso = []

Inflation_conso=wb.data.DataFrame('FP.CPI.TOTL.ZG', 
                    economy = code_country,
                      
                    time = range(1990, 2022), numericTimeKeys = True,
                    labels = True).set_index('Country')

for (column_name, column_data) in Inflation_conso.items():

    list_values_Inflation_conso.append(column_data.values)
    
list_values_Inflation_conso
# Out:
# [array([1.01534151]),
#  array([0.3870818]),
#  array([1.39378664]),
#  array([-1.00688169]),
#  array([39.16276738]),
#  array([16.43350345]),
#  array([4.6875]),
#  array([8.25082508]),
#  array([0.97533838]),
#  array([-0.05321362]),
#  array([1.86260595]),
#  array([3.91959134]),
#  array([3.05981858]),
#  array([-0.93000088]),
#  array([0.39307868]),
#  array([6.78292893]),
#  array([2.22897779]),
#  array([0.94567327]),
#  array([8.69482814]),
#  array([3.71360592]),
#  array([1.44594517]),
#  array([3.56351473]),
#  array([2.57718174]),
#  array([1.82539476]),
#  array([0.19087508]),
#  array([2.58500391]),
#  array([1.28544847]),
#  array([-0.98188987]),
#  array([0.92775543]),
#  array([0.67465277]),
#  array([1.69928463]),
#  array([4.18621507])]

# %%
import matplotlib.pyplot as plt
import numpy as np

years=np.arange(1990, 2022)
fig, ax1=plt.subplots()

ax1.set_xlabel('Year')
ax1.set_ylabel(f'Inflation, prix à la consommation (% annuel) in {country}', color='tab:blue')
ax1.plot(years, list_values_Inflation_conso, color='tab:blue', label=f'Inflation, prix à la consommation (% annuel) in {country}')
ax1.tick_params(axis='y', labelcolor='tab:blue')

plt.title(f'Inflation, prix à la consommation (% annuel) in {country}')
fig.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

years=np.arange(1990, 2022)
fig, ax1=plt.subplots(figsize=(12, 6))

ax1.set_xlabel('Year')
ax1.set_ylabel(f'Agriculture, valeur ajoutée in {country}', color='tab:green')
ax1.plot(years, list_values_Agriculture, color='tab:green', label=f'Agriculture in {country}')
ax1.tick_params(axis='y', labelcolor='tab:green')

ax2=ax1.twinx()
ax2.set_xlabel('Year')
ax2.set_ylabel(f'Industrie, valeur ajoutée (en $ US actuels) in {country}', color='tab:blue')
ax2.plot(years, list_values_Industrie_actu, color='tab:blue', label=f'Industrie, valeur ajoutée (en $ US actuels) in {country}')
ax2.tick_params(axis='y', labelcolor='tab:blue')

ax3=ax1.twinx()
ax3.spines['right'].set_position(('outward', 40))
ax3.set_ylabel(f'Industrie, valeur ajoutée (% du PIB) in {country}', color='tab:red')
ax3.plot(years, list_values_Industrie_PIB, color='tab:red', label=f'Industrie, valeur ajoutée (% du PIB) in {country}')
ax3.tick_params(axis='y', labelcolor='tab:red')

ax4=ax1.twinx()
ax4.spines['right'].set_position(('outward', 60))
ax4.set_ylabel(f'Industrie, valeur ajoutée (% de croissance annuelle) in {country}', color='tab:cyan')
ax4.plot(years, list_values_Industrie_croissance_annuelle, color='tab:cyan', label=f'Industrie, valeur ajoutée (% de croissance annuelle) in {country}')
ax4.tick_params(axis='y', labelcolor='tab:cyan')

ax5=ax1.twinx()
ax5.spines['right'].set_position(('outward', 80))
ax5.set_ylabel(f'Inflation, prix à la consommation (% annuel) in {country}', color='tab:gray')
ax5.plot(years, list_values_Inflation_conso, color='tab:gray', label=f'Inflation, prix à la consommation (% annuel) in {country}')
ax5.tick_params(axis='y', labelcolor='tab:gray')

plt.title(f'Agriculture, Industrie et inflation au Togo in {country}')
fig.tight_layout()
plt.show()

# %%
# Migration nette. SM.POP.NETM
# Population urbaine (% du total). SP.URB.TOTL.IN.ZS
# Croissance de la population rurale (% annuel). SP.RUR.TOTL.ZG
# Population, total. SP.POP.TOTL
# Croissance de la population (% annuel). SP.POP.GROW
# Croissance de la population urbaine (% annuel). SP.URB.GROW

# %%
Migration_nette = wb.data.DataFrame('SM.POP.NETM', code_country, range(1990, 2022)) 
Migration_nette
# Out:
#          YR1990  YR1991  YR1992    YR1993   YR1994   YR1995   YR1996   YR1997  \
# economy
# TGO        59.0   -72.0  -132.0 -291022.0  88992.0  57406.0  40915.0  11899.0
#
#           YR1998   YR1999  ...  YR2012  YR2013  YR2014  YR2015  YR2016  \
# economy                    ...
# TGO      12365.0  11122.0  ... -1992.0 -1985.0 -1985.0 -1985.0 -1988.0
#
#          YR2017  YR2018  YR2019  YR2020  YR2021
# economy
# TGO     -1997.0 -1997.0 -1997.0  -995.0  -995.0
#
# [1 rows x 32 columns]

# %%
Population_urbaine = wb.data.DataFrame('SP.URB.TOTL.IN.ZS', code_country, range(1990, 2022)) 
Population_urbaine
# Out:
#          YR1990  YR1991  YR1992  YR1993  YR1994  YR1995  YR1996  YR1997  \
# economy
# TGO      28.589  29.005  29.425  29.848  30.275  30.705  31.139  31.576
#
#          YR1998  YR1999  ...  YR2012  YR2013  YR2014  YR2015  YR2016  YR2017  \
# economy                  ...
# TGO      32.016   32.46  ...  38.546  39.061  39.579    40.1  40.628  41.162
#
#          YR2018  YR2019  YR2020  YR2021
# economy
# TGO      41.702  42.248    42.8  43.358
#
# [1 rows x 32 columns]

# %%
Croissance_pop_rurale = wb.data.DataFrame('SP.RUR.TOTL.ZG', code_country, range(1990, 2022)) 
Croissance_pop_rurale
# Out:
#            YR1990   YR1991    YR1992    YR1993    YR1994    YR1995    YR1996  \
# economy
# TGO      2.363234  2.32124  2.272409 -1.281134 -0.262484  3.848184  3.184405
#
#            YR1997    YR1998    YR1999  ...    YR2012    YR2013    YR2014  \
# economy                                ...
# TGO      2.609062  2.267841  2.255362  ...  1.769914  1.718212  1.677335
#
#            YR2015    YR2016    YR2017    YR2018    YR2019    YR2020    YR2021
# economy
# TGO      1.638517  1.600781  1.564608  1.516974  1.470655  1.430808  1.387019
#
# [1 rows x 32 columns]

# %%
Population_total = wb.data.DataFrame('SP.POP.TOTL', code_country, range(1990, 2022)) # PIB par habitant
Population_total
# Out:
#             YR1990     YR1991     YR1992     YR1993     YR1994     YR1995  \
# economy
# TGO      3875947.0  3990215.0  4106219.0  4078392.0  4092612.0  4279566.0
#
#             YR1996     YR1997     YR1998     YR1999  ...     YR2012  \
# economy                                              ...
# TGO      4445883.0  4592550.0  4728297.0  4867941.0  ...  6926635.0
#
#             YR2013     YR2014     YR2015     YR2016     YR2017     YR2018  \
# economy
# TGO      7106229.0  7288383.0  7473229.0  7661354.0  7852795.0  8046679.0
#
#             YR2019     YR2020     YR2021
# economy
# TGO      8243094.0  8442580.0  8644829.0
#
# [1 rows x 32 columns]

# %%
Croissance_population = wb.data.DataFrame('SP.POP.GROW', code_country, range(1990, 2022))
Croissance_population
# Out:
#            YR1990    YR1991    YR1992    YR1993   YR1994    YR1995   YR1996  \
# economy
# TGO      2.939893  2.905509  2.865754 -0.679986  0.34806  4.466821  3.81269
#
#            YR1997    YR1998    YR1999  ...    YR2012   YR2013    YR2014  \
# economy                                ...
# TGO      3.245693  2.912967  2.910596  ...  2.602838  2.55976  2.530999
#
#            YR2015    YR2016    YR2017    YR2018   YR2019    YR2020    YR2021
# economy
# TGO      2.504546  2.486156  2.468079  2.438994  2.41163  2.391219  2.367339
#
# [1 rows x 32 columns]

# %%
Croissance_population_urbaine = wb.data.DataFrame('SP.URB.GROW', code_country, range(1990, 2022))
Croissance_population_urbaine
# Out:
#            YR1990    YR1991    YR1992    YR1993    YR1994    YR1995   YR1996  \
# economy
# TGO      4.394996  4.350186  4.303389  0.747291  1.768519  5.877185  5.21626
#
#            YR1997    YR1998    YR1999  ...    YR2012    YR2013    YR2014  \
# economy                                ...
# TGO      4.639314  4.296811  4.287868  ...  3.945288  3.886965  3.848414
#
#            YR2015    YR2016    YR2017    YR2018    YR2019    YR2020   YR2021
# economy
# TGO      3.812321  3.794269  3.773863  3.742365  3.712415  3.689331  3.66266
#
# [1 rows x 32 columns]

# %%
wb.data.DataFrame(['SM.POP.NETM'],
                     code_country,
                      time=range(1990,2022,5)).plot.bar()
# Out:
# <Axes: xlabel='economy'>

# %%
wb.data.DataFrame(['SP.URB.TOTL.IN.ZS'],
                     code_country,
                      time=range(1990,2022,5)).plot.bar()
# Out:
# <Axes: xlabel='economy'>

# %%
wb.data.DataFrame(['SP.RUR.TOTL.ZG'],
                     code_country,
                      time=range(1990,2022,5)).plot.bar()
# Out:
# <Axes: xlabel='economy'>

# %%
wb.data.DataFrame(['SP.POP.TOTL'],
                     code_country,
                      time=range(1990,2022,5)).plot.bar()
# Out:
# <Axes: xlabel='economy'>

# %%
wb.data.DataFrame(['SP.POP.GROW'],
                     code_country,
                      time=range(1990,2022,5)).plot.bar()
# Out:
# <Axes: xlabel='economy'>

# %%
wb.data.DataFrame(['SP.URB.GROW'],
                     code_country,
                      time=range(1990,2022,5)).plot.bar()
# Out:
# <Axes: xlabel='economy'>

# %%
list_values_Migration_nette = []

Migration_nette=wb.data.DataFrame('SM.POP.NETM', 
                    economy = code_country,
                      
                    time = range(1990, 2022), numericTimeKeys = True,
                    labels = True).set_index('Country')

for (column_name, column_data) in Migration_nette.items():

    list_values_Migration_nette.append(column_data.values)
    
list_values_Migration_nette
# Out:
# [array([59.]),
#  array([-72.]),
#  array([-132.]),
#  array([-291022.]),
#  array([88992.]),
#  array([57406.]),
#  array([40915.]),
#  array([11899.]),
#  array([12365.]),
#  array([11122.]),
#  array([4710.]),
#  array([-1711.]),
#  array([-5972.]),
#  array([-2797.]),
#  array([-1007.]),
#  array([-4438.]),
#  array([21722.]),
#  array([4811.]),
#  array([14304.]),
#  array([-1997.]),
#  array([-1972.]),
#  array([-1980.]),
#  array([-1992.]),
#  array([-1985.]),
#  array([-1985.]),
#  array([-1985.]),
#  array([-1988.]),
#  array([-1997.]),
#  array([-1997.]),
#  array([-1997.]),
#  array([-995.]),
#  array([-995.])]

# %%
list_values_Population_urbaine = []

Population_urbaine=wb.data.DataFrame('SP.URB.TOTL.IN.ZS', 
                    economy = code_country,
                      
                    time = range(1990, 2022), numericTimeKeys = True,
                    labels = True).set_index('Country')

for (column_name, column_data) in Population_urbaine.items():

    list_values_Population_urbaine.append(column_data.values)
    
list_values_Population_urbaine
# Out:
# [array([28.589]),
#  array([29.005]),
#  array([29.425]),
#  array([29.848]),
#  array([30.275]),
#  array([30.705]),
#  array([31.139]),
#  array([31.576]),
#  array([32.016]),
#  array([32.46]),
#  array([32.907]),
#  array([33.356]),
#  array([33.809]),
#  array([34.265]),
#  array([34.724]),
#  array([35.185]),
#  array([35.649]),
#  array([36.116]),
#  array([36.587]),
#  array([37.058]),
#  array([37.533]),
#  array([38.032]),
#  array([38.546]),
#  array([39.061]),
#  array([39.579]),
#  array([40.1]),
#  array([40.628]),
#  array([41.162]),
#  array([41.702]),
#  array([42.248]),
#  array([42.8]),
#  array([43.358])]

# %%
list_values_Croissance_pop_rurale = []

Croissance_pop_rurale=wb.data.DataFrame('SP.RUR.TOTL.ZG', 
                    economy = code_country,
                      
                    time = range(1990, 2022), numericTimeKeys = True,
                    labels = True).set_index('Country')

for (column_name, column_data) in Croissance_pop_rurale.items():

    list_values_Croissance_pop_rurale.append(column_data.values)
    
list_values_Croissance_pop_rurale
# Out:
# [array([2.36323436]),
#  array([2.32124016]),
#  array([2.27240904]),
#  array([-1.28113426]),
#  array([-0.26248351]),
#  array([3.84818388]),
#  array([3.184405]),
#  array([2.6090616]),
#  array([2.26784097]),
#  array([2.25536189]),
#  array([2.17323991]),
#  array([2.0349909]),
#  array([1.92886262]),
#  array([1.91500934]),
#  array([1.92486829]),
#  array([1.88751629]),
#  array([2.0893279]),
#  array([2.17910247]),
#  array([2.1117734]),
#  array([2.04587807]),
#  array([1.9137981]),
#  array([1.8529216]),
#  array([1.76991366]),
#  array([1.71821239]),
#  array([1.67733492]),
#  array([1.63851733]),
#  array([1.60078089]),
#  array([1.56460835]),
#  array([1.5169736]),
#  array([1.47065504]),
#  array([1.43080833]),
#  array([1.38701924])]

# %%
list_values_Population_total = []

Population_total=wb.data.DataFrame('SP.POP.TOTL', 
                    economy = code_country,
                      
                    time = range(1990, 2022), numericTimeKeys = True,
                    labels = True).set_index('Country')

for (column_name, column_data) in Population_total.items():

    list_values_Population_total.append(column_data.values)
    
list_values_Population_total
# Out:
# [array([3875947.]),
#  array([3990215.]),
#  array([4106219.]),
#  array([4078392.]),
#  array([4092612.]),
#  array([4279566.]),
#  array([4445883.]),
#  array([4592550.]),
#  array([4728297.]),
#  array([4867941.]),
#  array([5008035.]),
#  array([5145426.]),
#  array([5281538.]),
#  array([5421001.]),
#  array([5565218.]),
#  array([5711597.]),
#  array([5874240.]),
#  array([6047537.]),
#  array([6222482.]),
#  array([6398624.]),
#  array([6571855.]),
#  array([6748672.]),
#  array([6926635.]),
#  array([7106229.]),
#  array([7288383.]),
#  array([7473229.]),
#  array([7661354.]),
#  array([7852795.]),
#  array([8046679.]),
#  array([8243094.]),
#  array([8442580.]),
#  array([8644829.])]

# %%
list_values_Croissance_population_urbaine = []

Croissance_population_urbaine=wb.data.DataFrame('SP.URB.GROW', 
                    economy = code_country,
                      
                    time = range(1990, 2022), numericTimeKeys = True,
                    labels = True).set_index('Country')

for (column_name, column_data) in Croissance_population_urbaine.items():

    list_values_Croissance_population_urbaine.append(column_data.values)
    
list_values_Croissance_population_urbaine
# Out:
# [array([4.39499619]),
#  array([4.35018551]),
#  array([4.30338925]),
#  array([0.74729082]),
#  array([1.76851939]),
#  array([5.87718499]),
#  array([5.21626001]),
#  array([4.63931397]),
#  array([4.29681111]),
#  array([4.28786806]),
#  array([4.20491371]),
#  array([4.06166814]),
#  array([3.95986221]),
#  array([3.94606335]),
#  array([3.95621798]),
#  array([3.915123]),
#  array([4.11795495]),
#  array([4.20889772]),
#  array([4.14747834]),
#  array([4.07055519]),
#  array([3.94493604]),
#  array([3.97571348]),
#  array([3.94528801]),
#  array([3.88696498]),
#  array([3.84841374]),
#  array([3.81232115]),
#  array([3.79426862]),
#  array([3.77386264]),
#  array([3.7423654]),
#  array([3.71241467]),
#  array([3.68933124]),
#  array([3.66265953])]

# %%
list_values_Croissance_population = []

Croissance_population=wb.data.DataFrame('SP.POP.GROW', 
                    economy = code_country,
                      
                    time = range(1990, 2022), numericTimeKeys = True,
                    labels = True).set_index('Country')

for (column_name, column_data) in Croissance_population.items():

    list_values_Croissance_population.append(column_data.values)
    
list_values_Croissance_population
# Out:
# [array([2.93989289]),
#  array([2.90550941]),
#  array([2.86575396]),
#  array([-0.67998607]),
#  array([0.34806039]),
#  array([4.46682056]),
#  array([3.81268968]),
#  array([3.2456926]),
#  array([2.912967]),
#  array([2.91059597]),
#  array([2.83725675]),
#  array([2.70645421]),
#  array([2.61091785]),
#  array([2.60631416]),
#  array([2.62556726]),
#  array([2.5962512]),
#  array([2.80780206]),
#  array([2.90743918]),
#  array([2.85177808]),
#  array([2.79141047]),
#  array([2.67131694]),
#  array([2.65496082]),
#  array([2.60283805]),
#  array([2.55975981]),
#  array([2.53099874]),
#  array([2.50454574]),
#  array([2.48615624]),
#  array([2.46807888]),
#  array([2.43899403]),
#  array([2.41162992]),
#  array([2.39121902]),
#  array([2.36733896])]

# %%
import matplotlib.pyplot as plt
import numpy as np

years=np.arange(1990, 2022)
fig, ax1=plt.subplots()

ax1.set_xlabel('Year')
ax1.set_ylabel(f'Migration nette in {country}', color='tab:blue')
ax1.plot(years, list_values_Migration_nette, color='tab:blue', label=f'Migration nette in {country}')
ax1.tick_params(axis='y', labelcolor='tab:blue')

plt.title(f'Migration nette in {country}')
fig.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

years=np.arange(1990, 2022)
fig, ax1=plt.subplots()

ax1.set_xlabel('Year')
ax1.set_ylabel(f'Population urbaine (% du total) in {country}', color='tab:blue')
ax1.plot(years, list_values_Population_urbaine, color='tab:blue', label=f'Population urbaine (% du total) in {country}')
ax1.tick_params(axis='y', labelcolor='tab:blue')

plt.title(f'Population urbaine (% du total) in {country}')
fig.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

years=np.arange(1990, 2022)
fig, ax1=plt.subplots()

ax1.set_xlabel('Year')
ax1.set_ylabel(f'Croissance de la population rurale (% annuel) in {country}', color='tab:blue')
ax1.plot(years, list_values_Croissance_pop_rurale, color='tab:blue', label=f'Croissance de la population rurale (% annuel) in {country}')
ax1.tick_params(axis='y', labelcolor='tab:blue')

plt.title(f'Croissance de la population rurale (% annuel) in {country}')
fig.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

years=np.arange(1990, 2022)
fig, ax1=plt.subplots()

ax1.set_xlabel('Year')
ax1.set_ylabel(f'Population, total in {country}', color='tab:blue')
ax1.plot(years, list_values_Population_total, color='tab:blue', label=f'Population, total in {country}')
ax1.tick_params(axis='y', labelcolor='tab:blue')

plt.title(f'Population, total in {country}')
fig.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

years=np.arange(1990, 2022)
fig, ax1=plt.subplots()

ax1.set_xlabel('Year')
ax1.set_ylabel(f'Croissance de la population (% annuel) in {country}', color='tab:blue')
ax1.plot(years, list_values_Croissance_population_urbaine, color='tab:blue', label=f'Croissance de la population (% annuel) in {country}')
ax1.tick_params(axis='y', labelcolor='tab:blue')

plt.title(f'Croissance de la population (% annuel) in {country}')
fig.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

years=np.arange(1990, 2022)
fig, ax1=plt.subplots()

ax1.set_xlabel('Year')
ax1.set_ylabel(f'Croissance de la population urbaine (% annuel) in {country}', color='tab:blue')
ax1.plot(years, list_values_Croissance_population, color='tab:blue', label=f'Croissance de la population urbaine (% annuel) in {country}')
ax1.tick_params(axis='y', labelcolor='tab:blue')

plt.title(f'Croissance de la population urbaine (% annuel) in {country}')
fig.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

years=np.arange(1990, 2022)
fig, ax1=plt.subplots(figsize=(12, 6))

ax1.set_xlabel('Year')
ax1.set_ylabel(f'Migration nette in {country}', color='tab:green')
ax1.plot(years, list_values_Migration_nette, color='tab:green', label=f'Migration nette in {country}')
ax1.tick_params(axis='y', labelcolor='tab:green')

ax2=ax1.twinx()
ax2.set_xlabel('Year')
ax2.set_ylabel(f'Population urbaine in {country}', color='tab:blue')
ax2.plot(years, list_values_Population_urbaine, color='tab:blue', label=f'Population urbaine in {country}')
ax2.tick_params(axis='y', labelcolor='tab:blue')

ax3=ax1.twinx()
ax3.spines['right'].set_position(('outward', 60))
ax3.set_ylabel(f'Population, total in {country}', color='tab:red')
ax3.plot(years, list_values_Population_total, color='tab:red', label=f'Population, total in {country}')
ax3.tick_params(axis='y', labelcolor='tab:red')

ax4=ax1.twinx()
ax4.spines['right'].set_position(('outward', 60))
ax4.set_ylabel(f'Croissance de la population in {country}', color='tab:cyan')
ax4.plot(years, list_values_Croissance_population, color='tab:cyan', label=f'Croissance de la population in {country}')
ax4.tick_params(axis='y', labelcolor='tab:cyan')

plt.title(f'Evolution de la population Togolaise in {country}')
fig.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

years=np.arange(1990, 2022)
fig, ax1=plt.subplots(figsize=(12, 6))

ax1.set_xlabel('Year')
ax1.set_ylabel(f'Migration nette in {country}', color='tab:green')
ax1.plot(years, list_values_Migration_nette, color='tab:green', label=f'Migration nette in {country}')
ax1.tick_params(axis='y', labelcolor='tab:green')

ax2=ax1.twinx()
ax2.spines['left'].set_position(('outward', 20))
ax2.set_xlabel('Year')
ax2.set_ylabel(f'Agriculture, valeur ajoutée (% de croissance annuelle) in {country}', color='tab:blue')
ax2.plot(years, list_values_Agriculture, color='tab:blue', label=f'Agriculture, valeur ajoutée (% de croissance annuelle) in {country}')
ax2.tick_params(axis='y', labelcolor='tab:blue')

ax3=ax1.twinx()
ax3.spines['right'].set_position(('outward', 20))
ax3.set_ylabel(f'Population, total in {country}', color='tab:red')
ax3.plot(years, list_values_Population_total, color='tab:red', label=f'Population, total in {country}')
ax3.tick_params(axis='y', labelcolor='tab:red')

ax4=ax1.twinx()
ax4.spines['right'].set_position(('outward', 40))
ax4.set_ylabel(f'Croissance de la population in {country}', color='tab:cyan')
ax4.plot(years, list_values_Croissance_population, color='tab:cyan', label=f'Croissance de la population in {country}')
ax4.tick_params(axis='y', labelcolor='tab:cyan')

ax5=ax1.twinx()
ax5.spines['right'].set_position(('outward', 60))
ax5.set_ylabel(f'Industrie, valeur ajoutée (% de croissance annuelle) in {country}', color='tab:gray')
ax5.plot(years, list_values_Industrie_croissance_annuelle, color='tab:gray', label=f'Industrie, valeur ajoutée (% de croissance annuelle) in {country}')
ax5.tick_params(axis='y', labelcolor='tab:gray')

ax6=ax1.twinx()
ax6.spines['right'].set_position(('outward', 80))
ax6.set_ylabel(f'Inflation, prix à la consommation (% annuel) in {country}', color='tab:orange')
ax6.plot(years, list_values_Inflation_conso, color='tab:orange', label=f'Inflation, prix à la consommation (% annuel) in {country}')
ax6.tick_params(axis='y', labelcolor='tab:orange')

plt.title(f'Evolution de la population Togolaise in {country}')
fig.tight_layout()
plt.show()

# %%
#QUESTION 5 : Analyse Comparative avec d'Autres Pays

# Croissance du PIB par habitant (% annuel). NY.GDP.PCAP.KD.ZG
# Croissance du PIB (% annuel). NY.GDP.MKTP.KD.ZG
# Taux de croissance moyen annualisé du niveau de vie par habitant, population totale (%). SI.SPR.PCAP.ZG


#Total de dette extérieure (% du RNB). DT.TDS.DECT.GN.ZS

# %%
countries_compare = []

for country in wb.region.members('WLD'):
    if country in ('TGO', "BEN", "RWA", "FRA", 'CAN'):
        countries_compare.append(country)
countries_compare = set(countries_compare)
wb.economy.info(countries_compare)
# Out:
# id    value       region    incomeLevel
# ----  ----------  --------  -------------
# BEN   Benin       SSF       LMC
# CAN   Canada      NAC       HIC
# FRA   France      ECS       HIC
# RWA   Rwanda      SSF       LIC
# TGO   Togo        SSF       LIC
#       5 elements

# %%
wb.economy.DataFrame(countries_compare)
# Out:
#        name  aggregate  longitude  latitude region adminregion lendingType  \
# id
# BEN   Benin      False    2.63230   6.47790    SSF         SSA         IDX
# CAN  Canada      False  -75.69190  45.42150    NAC                     LNX
# FRA  France      False    2.35097  48.85660    ECS                     LNX
# RWA  Rwanda      False   30.05870  -1.95325    SSF         SSA         IDX
# TGO    Togo      False    1.22550   6.12280    SSF         SSA         IDX
#
#     incomeLevel capitalCity
# id
# BEN         LMC  Porto-Novo
# CAN         HIC      Ottawa
# FRA         HIC       Paris
# RWA         LIC      Kigali
# TGO         LIC        Lome

# %%
wb.data.DataFrame(['NY.GDP.PCAP.KD.ZG', 'NY.GDP.MKTP.KD.ZG', 'SI.SPR.PCAP.ZG', 'GC.DOD.TOTL.GD.ZS'], 
                    economy = countries_compare,
               
                    timeColumns = True,
                    labels = True
                    )
# Out:
#                           Country  \
# economy series
# FRA     NY.GDP.PCAP.KD.ZG  France
# TGO     NY.GDP.PCAP.KD.ZG    Togo
# CAN     NY.GDP.PCAP.KD.ZG  Canada
# RWA     NY.GDP.PCAP.KD.ZG  Rwanda
# BEN     NY.GDP.PCAP.KD.ZG   Benin
# FRA     NY.GDP.MKTP.KD.ZG  France
# TGO     NY.GDP.MKTP.KD.ZG    Togo
# CAN     NY.GDP.MKTP.KD.ZG  Canada
# RWA     NY.GDP.MKTP.KD.ZG  Rwanda
# BEN     NY.GDP.MKTP.KD.ZG   Benin
# FRA     SI.SPR.PCAP.ZG     France
# TGO     SI.SPR.PCAP.ZG       Togo
# CAN     SI.SPR.PCAP.ZG     Canada
# RWA     SI.SPR.PCAP.ZG     Rwanda
# BEN     SI.SPR.PCAP.ZG      Benin
# FRA     GC.DOD.TOTL.GD.ZS  France
# TGO     GC.DOD.TOTL.GD.ZS    Togo
# CAN     GC.DOD.TOTL.GD.ZS  Canada
# RWA     GC.DOD.TOTL.GD.ZS  Rwanda
# BEN     GC.DOD.TOTL.GD.ZS   Benin
#
#                                                                       Series  \
# economy series
# FRA     NY.GDP.PCAP.KD.ZG                   GDP per capita growth (annual %)
# TGO     NY.GDP.PCAP.KD.ZG                   GDP per capita growth (annual %)
# CAN     NY.GDP.PCAP.KD.ZG                   GDP per capita growth (annual %)
# RWA     NY.GDP.PCAP.KD.ZG                   GDP per capita growth (annual %)
# BEN     NY.GDP.PCAP.KD.ZG                   GDP per capita growth (annual %)
# FRA     NY.GDP.MKTP.KD.ZG                              GDP growth (annual %)
# TGO     NY.GDP.MKTP.KD.ZG                              GDP growth (annual %)
# CAN     NY.GDP.MKTP.KD.ZG                              GDP growth (annual %)
# RWA     NY.GDP.MKTP.KD.ZG                              GDP growth (annual %)
# BEN     NY.GDP.MKTP.KD.ZG                              GDP growth (annual %)
# FRA     SI.SPR.PCAP.ZG     Annualized average growth rate in per capita r...
# TGO     SI.SPR.PCAP.ZG     Annualized average growth rate in per capita r...
# CAN     SI.SPR.PCAP.ZG     Annualized average growth rate in per capita r...
# RWA     SI.SPR.PCAP.ZG     Annualized average growth rate in per capita r...
# BEN     SI.SPR.PCAP.ZG     Annualized average growth rate in per capita r...
# FRA     GC.DOD.TOTL.GD.ZS          Central government debt, total (% of GDP)
# TGO     GC.DOD.TOTL.GD.ZS          Central government debt, total (% of GDP)
# CAN     GC.DOD.TOTL.GD.ZS          Central government debt, total (% of GDP)
# RWA     GC.DOD.TOTL.GD.ZS          Central government debt, total (% of GDP)
# BEN     GC.DOD.TOTL.GD.ZS          Central government debt, total (% of GDP)
#
#                            YR1960     YR1961     YR1962     YR1963     YR1964  \
# economy series
# FRA     NY.GDP.PCAP.KD.ZG     NaN   3.841055   5.682369   5.109072   5.461454
# TGO     NY.GDP.PCAP.KD.ZG     NaN  10.337165   2.068068   3.194618  11.967929
# CAN     NY.GDP.PCAP.KD.ZG     NaN   1.121346   5.445858   3.405213   4.650755
# RWA     NY.GDP.PCAP.KD.ZG     NaN  -6.825967   8.642566 -11.775520 -14.404949
# BEN     NY.GDP.PCAP.KD.ZG     NaN   1.567327  -4.993677   2.952293   4.762979
# FRA     NY.GDP.MKTP.KD.ZG     NaN   4.980112   6.843470   6.233680   6.652100
# TGO     NY.GDP.MKTP.KD.ZG     NaN  12.169317   3.773653   4.999694  14.286011
# CAN     NY.GDP.MKTP.KD.ZG     NaN   3.163292   7.425385   5.349546   6.642894
# RWA     NY.GDP.MKTP.KD.ZG     NaN  -4.297526  11.333798  -9.820444 -12.464993
# BEN     NY.GDP.MKTP.KD.ZG     NaN   3.141280  -3.426410   4.730028   6.650759
# FRA     SI.SPR.PCAP.ZG        NaN        NaN        NaN        NaN        NaN
# TGO     SI.SPR.PCAP.ZG        NaN        NaN        NaN        NaN        NaN
# CAN     SI.SPR.PCAP.ZG        NaN        NaN        NaN        NaN        NaN
# RWA     SI.SPR.PCAP.ZG        NaN        NaN        NaN        NaN        NaN
# BEN     SI.SPR.PCAP.ZG        NaN        NaN        NaN        NaN        NaN
# FRA     GC.DOD.TOTL.GD.ZS     NaN        NaN        NaN        NaN        NaN
# TGO     GC.DOD.TOTL.GD.ZS     NaN        NaN        NaN        NaN        NaN
# CAN     GC.DOD.TOTL.GD.ZS     NaN        NaN        NaN        NaN        NaN
# RWA     GC.DOD.TOTL.GD.ZS     NaN        NaN        NaN        NaN        NaN
# BEN     GC.DOD.TOTL.GD.ZS     NaN        NaN        NaN        NaN        NaN
#
#                               YR1965    YR1966    YR1967  ...     YR2013  \
# economy series                                            ...
# FRA     NY.GDP.PCAP.KD.ZG   3.693884  4.123017  3.843524  ...   0.058150
# TGO     NY.GDP.PCAP.KD.ZG  12.431521  5.801667  1.473366  ...   3.149795
# CAN     NY.GDP.PCAP.KD.ZG   4.409518  4.735676  1.252817  ...   1.253614
# RWA     NY.GDP.PCAP.KD.ZG   4.293540  4.045055  3.739979  ...   2.257667
# BEN     NY.GDP.PCAP.KD.ZG   3.360901  1.614800 -0.879980  ...   4.127606
# FRA     NY.GDP.MKTP.KD.ZG   4.861508  5.251837  4.921149  ...   0.576327
# TGO     NY.GDP.MKTP.KD.ZG  15.459713  9.408719  5.500372  ...   5.824266
# CAN     NY.GDP.MKTP.KD.ZG   6.316714  6.704992  3.091206  ...   2.329123
# RWA     NY.GDP.MKTP.KD.ZG   7.009529  7.008911  6.916018  ...   4.719850
# BEN     NY.GDP.MKTP.KD.ZG   5.293863  3.575863  1.078399  ...   7.191434
# FRA     SI.SPR.PCAP.ZG           NaN       NaN       NaN  ...        NaN
# TGO     SI.SPR.PCAP.ZG           NaN       NaN       NaN  ...        NaN
# CAN     SI.SPR.PCAP.ZG           NaN       NaN       NaN  ...        NaN
# RWA     SI.SPR.PCAP.ZG           NaN       NaN       NaN  ...        NaN
# BEN     SI.SPR.PCAP.ZG           NaN       NaN       NaN  ...        NaN
# FRA     GC.DOD.TOTL.GD.ZS        NaN       NaN       NaN  ...  90.968544
# TGO     GC.DOD.TOTL.GD.ZS        NaN       NaN       NaN  ...        NaN
# CAN     GC.DOD.TOTL.GD.ZS        NaN       NaN       NaN  ...  53.200869
# RWA     GC.DOD.TOTL.GD.ZS        NaN       NaN       NaN  ...        NaN
# BEN     GC.DOD.TOTL.GD.ZS        NaN       NaN       NaN  ...        NaN
#
#                               YR2014     YR2015      YR2016      YR2017  \
# economy series
# FRA     NY.GDP.PCAP.KD.ZG   0.484564   0.754024    0.829057    1.994998
# TGO     NY.GDP.PCAP.KD.ZG   2.993215   2.859340    1.655893    1.472334
# CAN     NY.GDP.PCAP.KD.ZG   1.841026  -0.089286   -0.135843    1.811279
# RWA     NY.GDP.PCAP.KD.ZG   3.672777   6.290306    3.413261    1.384346
# BEN     NY.GDP.PCAP.KD.ZG   3.290505  -1.181685    0.335852    2.603557
# FRA     NY.GDP.MKTP.KD.ZG   0.956183   1.112912    1.095464    2.291420
# TGO     NY.GDP.MKTP.KD.ZG   5.633240   5.468031    4.214896    4.007913
# CAN     NY.GDP.MKTP.KD.ZG   2.870036   0.659177    1.001394    3.039880
# RWA     NY.GDP.MKTP.KD.ZG   6.167167   8.856842    5.970756    3.928876
# BEN     NY.GDP.MKTP.KD.ZG   6.357679   1.778151    3.339673    5.671562
# FRA     SI.SPR.PCAP.ZG           NaN        NaN         NaN         NaN
# TGO     SI.SPR.PCAP.ZG           NaN   0.620000         NaN         NaN
# CAN     SI.SPR.PCAP.ZG           NaN        NaN         NaN         NaN
# RWA     SI.SPR.PCAP.ZG           NaN        NaN   -0.160000         NaN
# BEN     SI.SPR.PCAP.ZG           NaN   0.070000         NaN         NaN
# FRA     GC.DOD.TOTL.GD.ZS  97.554384  97.980333  102.262045  102.215265
# TGO     GC.DOD.TOTL.GD.ZS        NaN        NaN         NaN         NaN
# CAN     GC.DOD.TOTL.GD.ZS  51.482708  55.991584   56.023624   54.462565
# RWA     GC.DOD.TOTL.GD.ZS        NaN        NaN         NaN         NaN
# BEN     GC.DOD.TOTL.GD.ZS        NaN        NaN         NaN         NaN
#
#                                YR2018      YR2019      YR2020      YR2021  \
# economy series
# FRA     NY.GDP.PCAP.KD.ZG    1.500539    1.495899   -7.791009    6.131761
# TGO     NY.GDP.PCAP.KD.ZG    2.270153    2.422750   -0.251661    3.511857
# CAN     NY.GDP.PCAP.KD.ZG    1.335564    0.435426   -6.088212    4.409275
# RWA     NY.GDP.PCAP.KD.ZG    5.925179    6.876304   -5.664768    8.277013
# BEN     NY.GDP.PCAP.KD.ZG    3.624263    3.824507    0.951938    4.238709
# FRA     NY.GDP.MKTP.KD.ZG    1.865066    1.842972   -7.540459    6.435210
# TGO     NY.GDP.MKTP.KD.ZG    4.795183    4.922833    2.162287    5.991569
# CAN     NY.GDP.MKTP.KD.ZG    2.777041    1.888224   -5.074358    5.011801
# RWA     NY.GDP.MKTP.KD.ZG    8.536158    9.462286   -3.376517   10.875771
# BEN     NY.GDP.MKTP.KD.ZG    6.697254    6.865687    3.848792    7.155452
# FRA     SI.SPR.PCAP.ZG            NaN         NaN   -0.520000         NaN
# TGO     SI.SPR.PCAP.ZG            NaN         NaN         NaN         NaN
# CAN     SI.SPR.PCAP.ZG            NaN    0.780000         NaN         NaN
# RWA     SI.SPR.PCAP.ZG            NaN         NaN         NaN         NaN
# BEN     SI.SPR.PCAP.ZG            NaN         NaN         NaN         NaN
# FRA     GC.DOD.TOTL.GD.ZS  101.622134  104.961161  122.890486  116.488871
# TGO     GC.DOD.TOTL.GD.ZS         NaN         NaN         NaN         NaN
# CAN     GC.DOD.TOTL.GD.ZS   53.151536   53.362325   74.919955   71.286507
# RWA     GC.DOD.TOTL.GD.ZS         NaN         NaN         NaN         NaN
# BEN     GC.DOD.TOTL.GD.ZS         NaN         NaN         NaN         NaN
#
#                               YR2022
# economy series
# FRA     NY.GDP.PCAP.KD.ZG   2.142732
# TGO     NY.GDP.PCAP.KD.ZG   3.372720
# CAN     NY.GDP.PCAP.KD.ZG   1.569015
# RWA     NY.GDP.PCAP.KD.ZG   5.688821
# BEN     NY.GDP.PCAP.KD.ZG   3.420679
# FRA     NY.GDP.MKTP.KD.ZG   2.454758
# TGO     NY.GDP.MKTP.KD.ZG   5.810547
# CAN     NY.GDP.MKTP.KD.ZG   3.437982
# RWA     NY.GDP.MKTP.KD.ZG   8.160384
# BEN     NY.GDP.MKTP.KD.ZG   6.253245
# FRA     SI.SPR.PCAP.ZG           NaN
# TGO     SI.SPR.PCAP.ZG           NaN
# CAN     SI.SPR.PCAP.ZG           NaN
# RWA     SI.SPR.PCAP.ZG           NaN
# BEN     SI.SPR.PCAP.ZG           NaN
# FRA     GC.DOD.TOTL.GD.ZS        NaN
# TGO     GC.DOD.TOTL.GD.ZS        NaN
# CAN     GC.DOD.TOTL.GD.ZS  62.094230
# RWA     GC.DOD.TOTL.GD.ZS        NaN
# BEN     GC.DOD.TOTL.GD.ZS        NaN
#
# [20 rows x 65 columns]

# %%
Croissance_PIB_HA =wb.data.DataFrame('NY.GDP.PCAP.KD.ZG', 
                    economy = countries_compare, 
                    time = range(2000, 2022), numericTimeKeys = True,
                    labels = True).set_index('Country')
Croissance_PIB_HA
# Out:
#              2000      2001       2002      2003      2004      2005  \
# Country
# France   3.212385  1.242527   0.401189  0.109403  2.076625  0.903680
# Togo    -3.558947 -1.868706   1.150878  3.974642 -3.544703 -7.109548
# Canada   4.202683  0.690161   1.903852  0.888030  2.129631  2.234059
# Rwanda   7.029241  6.981408  11.186203 -0.131839  4.711798  6.536954
# Benin    2.689647  2.207365   1.548959  0.372025  1.316512 -1.467814
#
#              2006      2007      2008      2009  ...      2012      2013  \
# Country                                          ...
# France   1.741085  1.795236 -0.302484 -3.370397  ... -0.171161  0.058150
# Togo    -0.191993 -4.007026  1.110684  2.550880  ...  3.571507  3.149795
# Canada   1.602575  1.085367 -0.083592 -4.028003  ...  0.662001  1.253614
# Rwanda   6.354831  4.772671  8.219969  3.479418  ...  6.001706  2.257667
# Benin    0.811410  2.982053  1.849625 -0.648437  ...  1.800064  4.127606
#
#              2014      2015      2016      2017      2018      2019      2020  \
# Country
# France   0.484564  0.754024  0.829057  1.994998  1.500539  1.495899 -7.791009
# Togo     2.993215  2.859340  1.655893  1.472334  2.270153  2.422750 -0.251661
# Canada   1.841026 -0.089286 -0.135843  1.811279  1.335564  0.435426 -6.088212
# Rwanda   3.672777  6.290306  3.413261  1.384346  5.925179  6.876304 -5.664768
# Benin    3.290505 -1.181685  0.335852  2.603557  3.624263  3.824507  0.951938
#
#              2021
# Country
# France   6.131761
# Togo     3.511857
# Canada   4.409275
# Rwanda   8.277013
# Benin    4.238709
#
# [5 rows x 22 columns]

# %%
list_values_Croissance_PIB_HA = []
# Croissance du PIB par habitant
Croissance_PIB_HA=wb.data.DataFrame('NY.GDP.PCAP.KD.ZG', 
                    economy = countries_compare,
                      
                    time = range(1990, 2022), numericTimeKeys = True,
                    labels = True).set_index('Country')

for (column_name, column_data) in Croissance_PIB_HA.items():

    list_values_Croissance_PIB_HA.append(column_data.values)
    
list_values_Croissance_PIB_HA
# Out:
# [array([ 2.43024697, -3.13369561, -1.33414395, -4.77249399,  5.71244559]),
#  array([ 0.16314633, -3.54362783, -3.2953917 , -4.67252926,  1.08257118]),
#  array([ 1.09459803, -6.69330989, -0.28703143,  3.50109959, -0.14985962]),
#  array([ -1.05943733, -14.51652358,   1.53886102, -10.98621085,
#           1.22888349]),
#  array([  1.97639228,  14.58290178,   3.3562268 , -41.58686137,
#          -1.72072453]),
#  array([ 1.73610124,  3.13455792,  1.6368094 , 60.09054133,  3.88594239]),
#  array([ 1.05172456,  4.76473422,  0.56246786, -4.52353448,  1.67829883]),
#  array([ 1.97211924, 10.7246385 ,  3.24884931, -0.27574313,  2.70244772]),
#  array([ 3.20515306, -5.10479738,  3.03747599,  5.44885398,  0.84800005]),
#  array([ 2.88869862, -0.45808734,  4.31156937,  3.11494852,  2.16959373]),
#  array([ 3.21238485, -3.55894727,  4.20268257,  7.02924095,  2.68964738]),
#  array([ 1.24252729, -1.86870629,  0.69016125,  6.981408  ,  2.20736492]),
#  array([ 0.40118913,  1.15087751,  1.903852  , 11.18620306,  1.54895925]),
#  array([ 0.10940298,  3.97464246,  0.88803015, -0.13183938,  0.3720248 ]),
#  array([ 2.07662491, -3.54470315,  2.12963094,  4.71179812,  1.31651204]),
#  array([ 0.90368039, -7.10954805,  2.23405943,  6.53695402, -1.46781382]),
#  array([ 1.74108526, -0.19199308,  1.60257476,  6.3548307 ,  0.81141016]),
#  array([ 1.79523637, -4.0070262 ,  1.08536734,  4.77267138,  2.98205332]),
#  array([-0.30248383,  1.11068447, -0.08359243,  8.219969  ,  1.84962507]),
#  array([-3.37039728,  2.55087994, -4.02800308,  3.47941821, -0.64843689]),
#  array([ 1.44824526,  3.06408185,  1.95004833,  4.57248372, -0.83935582]),
#  array([ 1.7006104 ,  3.05065491,  2.14153573,  5.22393751, -0.00742819]),
#  array([-0.17116134,  3.57150681,  0.66200065,  6.00170618,  1.80006449]),
#  array([0.05814951, 3.14979486, 1.25361381, 2.25766716, 4.12760623]),
#  array([0.48456445, 2.99321468, 1.84102612, 3.67277671, 3.290505  ]),
#  array([ 0.75402435,  2.8593405 , -0.0892858 ,  6.29030595, -1.18168484]),
#  array([ 0.82905666,  1.65589269, -0.13584262,  3.41326078,  0.33585225]),
#  array([1.99499845, 1.47233402, 1.81127892, 1.38434575, 2.60355653]),
#  array([1.50053912, 2.2701529 , 1.33556429, 5.92517941, 3.62426255]),
#  array([1.49589899, 2.42275032, 0.43542634, 6.87630419, 3.82450688]),
#  array([-7.79100851, -0.25166105, -6.08821205, -5.66476815,  0.95193786]),
#  array([6.13176132, 3.51185684, 4.40927515, 8.27701329, 4.23870896])]

# %%
wb.data.DataFrame('NY.GDP.PCAP.KD.ZG', 
                    economy = countries_compare, 
                    time = range(2000, 2022), numericTimeKeys = True,
                    labels = True).set_index('Country').transpose().plot(title='Croissance PIB par Habitant');

# %%
wb.data.DataFrame('NY.GDP.PCAP.KD.ZG', 
                    economy = countries_compare, 
                    time = range(2005, 2008), numericTimeKeys = True,
                    labels = True).set_index('Country').transpose().plot(title='Croissance du PIB (% annuel)'); 
#avant crise éconoique mondiale

# %%
wb.data.DataFrame('NY.GDP.PCAP.KD.ZG', 
                    economy = countries_compare, 
                    time = range(2008, 2010), numericTimeKeys = True,
                    labels = True).set_index('Country').transpose().plot(title='Croissance du PIB (% annuel)');
#période crise économique

# %%
wb.data.DataFrame('NY.GDP.PCAP.KD.ZG', 
                    economy = countries_compare, 
                    time = range(2020, 2022), numericTimeKeys = True,
                    labels = True).set_index('Country').transpose().plot(title='Croissance du PIB (% annuel)');
#période covid19

# %%
# Croissance du PIB (% annuel). NY.GDP.MKTP.KD.ZG

# %%
Croissance_PIB_annuel =wb.data.DataFrame('NY.GDP.MKTP.KD.ZG', 
                    economy = countries_compare, 
                    time = range(1990, 2022), numericTimeKeys = True,
                    labels = True).set_index('Country')
Croissance_PIB_annuel
# Out:
#              1990      1991      1992       1993       1994       1995  \
# Country
# France   2.923935  1.048176  1.599343  -0.628666   2.358408   2.106629
# Togo    -0.243656 -0.699967 -3.980687 -15.095827  14.982414   7.845832
# Canada   0.164672 -2.086085  0.900260   2.660857   4.494466   2.693976
# Rwanda  -2.399291 -2.514380  5.872725  -8.108692 -50.248067  35.224078
# Benin    8.976134  4.225799  2.957711   5.836172   2.020400   6.045199
#
#               1996       1997      1998      1999  ...      2012      2013  \
# Country                                            ...
# France    1.412994   2.336297  3.588659  3.421374  ...  0.313135  0.576327
# Togo      8.836212  14.377378 -2.299877  2.481751  ...  6.302695  5.824266
# Canada    1.619172   4.280040  3.896152  5.162914  ...  1.760962  2.329123
# Rwanda   12.745696  13.849752  8.858669  4.351888  ...  8.641513  4.719850
# Benin     4.324284   5.734688  3.961012  5.341449  ...  4.811223  7.191434
#
#              2014      2015      2016      2017      2018      2019      2020  \
# Country
# France   0.956183  1.112912  1.095464  2.291420  1.865066  1.842972 -7.540459
# Togo     5.633240  5.468031  4.214896  4.007913  4.795183  4.922833  2.162287
# Canada   2.870036  0.659177  1.001394  3.039880  2.777041  1.888224 -5.074358
# Rwanda   6.167167  8.856842  5.970756  3.928876  8.536158  9.462286 -3.376517
# Benin    6.357679  1.778151  3.339673  5.671562  6.697254  6.865687  3.848792
#
#               2021
# Country
# France    6.435210
# Togo      5.991569
# Canada    5.011801
# Rwanda   10.875771
# Benin     7.155452
#
# [5 rows x 32 columns]

# %%
list_values_Croissance_PIB_annuel = []
# Croissance du PIB par habitant
Croissance_PIB_annuel=wb.data.DataFrame('NY.GDP.MKTP.KD.ZG', 
                    economy = countries_compare,
                      
                    time = range(1990, 2022), numericTimeKeys = True,
                    labels = True).set_index('Country')

for (column_name, column_data) in Croissance_PIB_annuel.items():

    list_values_Croissance_PIB_annuel.append(column_data.values)
    
list_values_Croissance_PIB_annuel
# Out:
# [array([ 2.92393508, -0.24365613,  0.1646725 , -2.3992911 ,  8.97613436]),
#  array([ 1.04817585, -0.69996749, -2.08608549, -2.51437965,  4.22579942]),
#  array([ 1.59934268, -3.98068681,  0.90025956,  5.87272524,  2.95771083]),
#  array([ -0.62866635, -15.09582749,   2.6608566 ,  -8.10869188,
#           5.83617209]),
#  array([  2.35840844,  14.98241435,   4.49446621, -50.24806711,
#           2.02040045]),
#  array([ 2.10662916,  7.84583232,  2.69397628, 35.22407831,  6.04519865]),
#  array([ 1.41299367,  8.83621163,  1.61917249, 12.74569576,  4.32428403]),
#  array([ 2.33629653, 14.37737757,  4.28004003, 13.84975248,  5.73468838]),
#  array([ 3.58865943, -2.29987657,  3.89615183,  8.85866949,  3.96101214]),
#  array([3.4213738 , 2.48175144, 5.16291362, 4.35188832, 5.34144937]),
#  array([ 3.92366923, -0.78347961,  5.17763567,  8.3708769 ,  5.85771421]),
#  array([1.98372142, 0.82343875, 1.78997288, 8.48458457, 5.33313571]),
#  array([ 1.13553148,  3.82662258,  3.01805051, 13.19207117,  4.64303087]),
#  array([0.82316076, 6.72017142, 1.80151814, 2.20238024, 3.44357678]),
#  array([ 2.82975293, -0.97866534,  3.08698081,  7.44766527,  4.42968455]),
#  array([ 1.66321998, -4.66629938,  3.20420043,  9.3778981 ,  1.71316456]),
#  array([2.4493236 , 2.6501321 , 2.63430381, 9.22708189, 3.94373883]),
#  array([ 2.42473624, -1.17512039,  2.07182503,  7.63329532,  5.98634932]),
#  array([ 0.25494596,  4.03564527,  1.0042892 , 11.16125473,  4.89657708]),
#  array([-2.87331383,  5.45382399, -2.92595565,  6.24826072,  2.31929214]),
#  array([1.94943762, 5.85435269, 3.08991946, 7.33464809, 2.11406473]),
#  array([2.19270063, 5.82325224, 3.14610049, 7.95839413, 2.96375292]),
#  array([0.31313475, 6.30269542, 1.76096159, 8.6415134 , 4.81122332]),
#  array([0.57632667, 5.82426583, 2.32912251, 4.71985027, 7.19143372]),
#  array([0.95618305, 5.63324022, 2.87003608, 6.16716724, 6.3576791 ]),
#  array([1.11291234, 5.46803129, 0.65917686, 8.856842  , 1.77815106]),
#  array([1.0954644 , 4.21489561, 1.00139441, 5.9707562 , 3.33967343]),
#  array([2.29141999, 4.0079126 , 3.03988023, 3.92887559, 5.67156195]),
#  array([1.86506607, 4.79518333, 2.77704055, 8.53615838, 6.69725362]),
#  array([1.84297181, 4.92283321, 1.88822359, 9.46228643, 6.86568663]),
#  array([-7.54045916,  2.16228657, -5.07435757, -3.37651719,  3.8487924 ]),
#  array([ 6.43520962,  5.99156915,  5.01180088, 10.87577125,  7.15545165])]

# %%
wb.data.DataFrame('NY.GDP.MKTP.KD.ZG', 
                    economy = countries_compare, 
                    time = range(1990, 2021), numericTimeKeys = True,
                    labels = True).set_index('Country').transpose().plot(title='Croissance du PIB (% annuel)');

# %%
wb.data.DataFrame('NY.GDP.MKTP.KD.ZG', 
                    economy = countries_compare, 
                    time = range(2005, 2008), numericTimeKeys = True,
                    labels = True).set_index('Country').transpose().plot(title='Croissance du PIB (% annuel)'); 
#avant crise éconoique mondiale

# %%
wb.data.DataFrame('NY.GDP.MKTP.KD.ZG', 
                    economy = countries_compare, 
                    time = range(2008, 2010), numericTimeKeys = True,
                    labels = True).set_index('Country').transpose().plot(title='Croissance du PIB (% annuel)');
#période crise économique

# %%
# Using graph_objects
import plotly.graph_objects as go
import pandas as pd

df = wb.data.DataFrame(['NY.GDP.MKTP.KD.ZG'], economy = countries_compare,
                                time=range(2020, 2022),
                                labels=True,
                                skipAggs=True, 
                                skipBlanks=True, 
                                columns='series').sort_values(by=['NY.GDP.MKTP.KD.ZG'])
fig = go.Figure([go.Scatter(x=df['Time'], y=df['NY.GDP.MKTP.KD.ZG'])])
# fig.show()
df
# Out:
#                Country  Time  NY.GDP.MKTP.KD.ZG
# economy time
# FRA     YR2020  France  2020          -7.540459
# CAN     YR2020  Canada  2020          -5.074358
# RWA     YR2020  Rwanda  2020          -3.376517
# TGO     YR2020    Togo  2020           2.162287
# BEN     YR2020   Benin  2020           3.848792
# CAN     YR2021  Canada  2021           5.011801
# TGO     YR2021    Togo  2021           5.991569
# FRA     YR2021  France  2021           6.435210
# BEN     YR2021   Benin  2021           7.155452
# RWA     YR2021  Rwanda  2021          10.875771

# %%
df = wb.data.DataFrame(['NY.GDP.MKTP.KD.ZG'], 
                                economy = countries_compare,
                                time=range(2018, 2022),
                                labels=True,
                                skipAggs=True, 
                                skipBlanks=True, 
                       columns='series'
                               ).sort_values(by=['NY.GDP.MKTP.KD.ZG'])
df.head() # set_index('NY.GDP.MKTP.KD.ZG')

df_wide = df.pivot(index="Time", columns="Country", values="NY.GDP.MKTP.KD.ZG")
df_wide.head()
# Out:
# Country     Benin    Canada    France     Rwanda      Togo
# Time
# 2018     6.697254  2.777041  1.865066   8.536158  4.795183
# 2019     6.865687  1.888224  1.842972   9.462286  4.922833
# 2020     3.848792 -5.074358 -7.540459  -3.376517  2.162287
# 2021     7.155452  5.011801  6.435210  10.875771  5.991569

# %%
import seaborn as sns
sns.lineplot(data=df_wide)
# Out:
# <Axes: xlabel='Time'>

# %%
# wb.data.DataFrame('NY.GDP.MKTP.KD.ZG', 
#                     economy = countries_compare, 
#                     time = range(2020, 2022), numericTimeKeys = True,
#                     labels = True).set_index('Country')#.transpose().plot(title='Croissance du PIB (% annuel)')

wb.data.DataFrame(['NY.GDP.MKTP.KD.ZG'], economy = countries_compare,
                                time=range(2020, 2022),
                                labels=True,
                                skipAggs=True, 
                                skipBlanks=True, 
                                columns='series').sort_values(by=['time']).plot(title='Croissance du PIB (% annuel)')
#période covid19
# Out:
# <Axes: title={'center': 'Croissance du PIB (%\xa0annuel)'}, xlabel='economy,time'>

# %%
# Taux de croissance moyen annualisé du niveau de vie par habitant, population totale (%). SI.SPR.PCAP.ZG

# %%
Croissance_annuel_pop_tot =wb.data.DataFrame('SI.SPR.PCAP.ZG', 
                    economy = countries_compare, 
                    time = range(2000, 2022), numericTimeKeys = True,
                    labels = True).set_index('Country')
Croissance_annuel_pop_tot
# Out:
#          2000  2001  2002  2003  2004  2005  2006  2007  2008  2009  ...  \
# Country                                                              ...
# France    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# Togo      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# Canada    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# Rwanda    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# Benin     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
#
#          2012  2013  2014  2015  2016  2017  2018  2019  2020  2021
# Country
# France    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN -0.52   NaN
# Togo      NaN   NaN   NaN  0.62   NaN   NaN   NaN   NaN   NaN   NaN
# Canada    NaN   NaN   NaN   NaN   NaN   NaN   NaN  0.78   NaN   NaN
# Rwanda    NaN   NaN   NaN   NaN -0.16   NaN   NaN   NaN   NaN   NaN
# Benin     NaN   NaN   NaN  0.07   NaN   NaN   NaN   NaN   NaN   NaN
#
# [5 rows x 22 columns]

# %%
list_values_Croissance_annuel_pop_tot = []

Croissance_annuel_pop_tot=wb.data.DataFrame('EN.POP.DNST', 
                    economy = countries_compare,
                      
                    time = range(1990, 2022), numericTimeKeys = True,
                    labels = True).set_index('Country')

for (column_name, column_data) in Croissance_annuel_pop_tot.items():

    list_values_Croissance_annuel_pop_tot.append(column_data.values)
    
Croissance_annuel_pop_tot
# Out:
#                1990        1991        1992        1993        1994  \
# Country
# France   106.004940  106.941587  107.475524  107.943455  108.347825
# Togo      71.262125   73.363026   75.495845   74.984225   75.245670
# Canada     3.088602    3.127225    3.164461    3.199428    3.234663
# Rwanda   296.715120  303.432550  310.385407  320.419133  272.908999
# Benin     45.525177   46.940812   48.401720   50.604656   52.530986
#
#                1995        1996        1997        1998        1999  ...  \
# Country                                                              ...
# France   108.742433  109.131197  109.520942  109.927917  110.497036  ...
# Togo      78.682956   81.740816   84.437397   86.933205   89.500662  ...
# Canada     3.268308    3.302651    3.335636    3.363434    3.390885  ...
# Rwanda   230.518727  272.213620  310.771463  320.820632  324.669112  ...
# Benin     53.622836   55.018269   56.642657   58.391123   60.203875  ...
#
#                2012        2013        2014        2015        2016  \
# Country
# France   119.918547  120.539577  121.105322  121.536702  121.857823
# Togo     127.351259  130.653227  134.002261  137.400791  140.859607
# Canada     3.871939    3.913067    3.952605    3.982215    4.027564
# Rwanda   439.413620  449.993920  460.820876  471.948075  483.619741
# Benin     88.808780   91.421869   94.136609   96.956217   99.858860
#
#                2017        2018        2019        2020        2021
# Country
# France   122.211971  122.650880  123.070294  123.404699  123.757534
# Togo     144.379390  147.944089  151.555323  155.223019  158.941515
# Canada     4.076166    4.134149    4.193949    4.239226    4.349505
# Rwanda   495.757560  507.977625  520.268666  532.888610  545.678476
# Benin    102.844794  105.894670  108.996488  112.124184  115.261573
#
# [5 rows x 32 columns]

# %%
wb.data.DataFrame('SI.SPR.PCAP.ZG', 
                    economy = countries_compare, 
                    time = range(1990, 2022), numericTimeKeys = True,
                    labels = True).set_index('Country').transpose().plot(title='Taux de croissance moyen annualisé du niveau de vie par habitant');

# %%
#Total de dette extérieure (% du RNB). DT.TDS.DECT.GN.ZS

# %%
Dette_gouv_central =wb.data.DataFrame('DT.TDS.DECT.GN.ZS', 
                    economy = countries_compare, 
                    time = range(1990, 2022), numericTimeKeys = True,
                    labels = True).set_index('Country')
Dette_gouv_central
# Out:
#              1990      1991      1992      1993      1994      1995      1996  \
# Country
# France        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# Togo     5.360268  3.446511  2.169037  2.192849  2.458467  2.299128  4.044255
# Canada        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# Rwanda   0.827297  1.229508  1.052633  1.099336  0.557675  1.558205  1.285822
# Benin    1.931199  1.547161  1.684199  1.414043  2.536299  2.262088  1.896121
#
#              1997      1998      1999  ...      2012      2013      2014  \
# Country                                ...
# France        NaN       NaN       NaN  ...       NaN       NaN       NaN
# Togo     3.803279  2.547898  2.758900  ...  0.431451  0.867374  0.949499
# Canada        NaN       NaN       NaN  ...       NaN       NaN       NaN
# Rwanda   1.211207  1.054039  1.527387  ...  1.130032  1.420753  2.105094
# Benin    2.323011  2.415561  1.903488  ...  0.532374  0.675091  0.598908
#
#              2015      2016      2017      2018      2019      2020      2021
# Country
# France        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# Togo     1.028671  1.474230  1.677285  1.634388  1.626123  1.397133  2.025680
# Canada        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# Rwanda   2.203239  2.627631  2.730462  2.830963  3.250293  2.855222  5.727663
# Benin    0.692155  0.841773  0.828445  1.640607  3.616704  1.550327  4.246747
#
# [5 rows x 32 columns]

# %%
list_values_Croissance_annuel_pop_tot = []

Croissance_annuel_pop_tot=wb.data.DataFrame('SI.SPR.PCAP.ZG', 
                    economy = countries_compare,
                      
                    time = range(1990, 2022), numericTimeKeys = True,
                    labels = True).set_index('Country')

for (column_name, column_data) in Croissance_annuel_pop_tot.items():

    list_values_Croissance_annuel_pop_tot.append(column_data.values)
    
list_values_Croissance_annuel_pop_tot
# Out:
# [array([nan, nan, nan, nan, nan]),
#  array([nan, nan, nan, nan, nan]),
#  array([nan, nan, nan, nan, nan]),
#  array([nan, nan, nan, nan, nan]),
#  array([nan, nan, nan, nan, nan]),
#  array([nan, nan, nan, nan, nan]),
#  array([nan, nan, nan, nan, nan]),
#  array([nan, nan, nan, nan, nan]),
#  array([nan, nan, nan, nan, nan]),
#  array([nan, nan, nan, nan, nan]),
#  array([nan, nan, nan, nan, nan]),
#  array([nan, nan, nan, nan, nan]),
#  array([nan, nan, nan, nan, nan]),
#  array([nan, nan, nan, nan, nan]),
#  array([nan, nan, nan, nan, nan]),
#  array([nan, nan, nan, nan, nan]),
#  array([nan, nan, nan, nan, nan]),
#  array([nan, nan, nan, nan, nan]),
#  array([nan, nan, nan, nan, nan]),
#  array([nan, nan, nan, nan, nan]),
#  array([nan, nan, nan, nan, nan]),
#  array([nan, nan, nan, nan, nan]),
#  array([nan, nan, nan, nan, nan]),
#  array([nan, nan, nan, nan, nan]),
#  array([nan, nan, nan, nan, nan]),
#  array([ nan, 0.62,  nan,  nan, 0.07]),
#  array([  nan,   nan,   nan, -0.16,   nan]),
#  array([nan, nan, nan, nan, nan]),
#  array([nan, nan, nan, nan, nan]),
#  array([ nan,  nan, 0.78,  nan,  nan]),
#  array([-0.52,   nan,   nan,   nan,   nan]),
#  array([nan, nan, nan, nan, nan])]

# %%
list_values_Dette_gouv_central = []

Dette_gouv_central=wb.data.DataFrame('DT.TDS.DECT.GN.ZS', 
                    economy = countries_compare,
                      
                    time = range(1990, 2022), numericTimeKeys = True,
                    labels = True).set_index('Country')

for (column_name, column_data) in Dette_gouv_central.items():

    list_values_Dette_gouv_central.append(column_data.values)
    
list_values_Dette_gouv_central
# Out:
# [array([       nan, 5.3602677 ,        nan, 0.82729687, 1.93119933]),
#  array([       nan, 3.44651141,        nan, 1.22950813, 1.54716053]),
#  array([       nan, 2.16903736,        nan, 1.05263257, 1.68419893]),
#  array([       nan, 2.19284874,        nan, 1.09933595, 1.41404274]),
#  array([       nan, 2.45846736,        nan, 0.55767505, 2.53629865]),
#  array([       nan, 2.29912841,        nan, 1.558205  , 2.26208794]),
#  array([       nan, 4.04425515,        nan, 1.28582217, 1.89612055]),
#  array([       nan, 3.80327854,        nan, 1.21120749, 2.32301138]),
#  array([       nan, 2.54789752,        nan, 1.05403923, 2.41556065]),
#  array([       nan, 2.75889958,        nan, 1.52738724, 1.90348763]),
#  array([       nan, 2.06741488,        nan, 1.77289982, 2.16968546]),
#  array([       nan, 2.35893599,        nan, 1.05534217, 1.30889261]),
#  array([       nan, 0.87956094,        nan, 0.97398012, 1.3735636 ]),
#  array([       nan, 0.92603312,        nan, 1.06059837, 0.94834879]),
#  array([       nan, 0.98777719,        nan, 1.14104344, 0.66756588]),
#  array([       nan, 0.94606493,        nan, 0.97149987, 0.7395727 ]),
#  array([       nan, 1.15625614,        nan, 0.81351061, 0.60000674]),
#  array([       nan, 0.41423549,        nan, 0.58192149, 0.45283323]),
#  array([       nan, 4.27836325,        nan, 0.93039652, 0.30825411]),
#  array([       nan, 1.14474577,        nan, 0.700587  , 0.49125697]),
#  array([       nan, 0.7718492 ,        nan, 0.85529987, 0.46221377]),
#  array([       nan, 0.26840643,        nan, 0.68059784, 0.47024751]),
#  array([       nan, 0.43145087,        nan, 1.13003197, 0.53237352]),
#  array([      nan, 0.8673745,       nan, 1.4207533, 0.675091 ]),
#  array([       nan, 0.94949887,        nan, 2.10509414, 0.59890841]),
#  array([       nan, 1.02867055,        nan, 2.20323859, 0.69215547]),
#  array([       nan, 1.47423031,        nan, 2.62763057, 0.84177332]),
#  array([       nan, 1.67728534,        nan, 2.73046219, 0.82844491]),
#  array([       nan, 1.63438844,        nan, 2.83096285, 1.64060704]),
#  array([       nan, 1.62612254,        nan, 3.25029304, 3.61670403]),
#  array([       nan, 1.39713294,        nan, 2.85522195, 1.55032656]),
#  array([       nan, 2.02568003,        nan, 5.72766291, 4.24674666])]

# %%
wb.data.DataFrame('DT.TDS.DECT.GN.ZS', 
                    economy = countries_compare, 
                    time = range(2000, 2022), numericTimeKeys = True,
                    labels = True).set_index('Country').transpose().plot(title='Total de dette extérieure');

# %%
wb.data.DataFrame('DT.TDS.DECT.GN.ZS', 
                    economy = countries_compare, 
                    time = range(2005, 2010), numericTimeKeys = True,
                    labels = True).set_index('Country').transpose().plot(title='Total de dette extérieure entre 2005 et 2010');
